# %%
import os
import csv
import pandas as pd
import numpy as np
import boto3
from IPython.display import clear_output
import ast
import pymongo as pm
from bson.objectid import ObjectId

# %%
#read the csv file and select target columns
fname = 'MuseumStation_AllDescriptives_14447_images_final_cdm_run_v5.csv'
version = 'cdm_run_v5'

data = pd.read_csv(fname)
data = data[['session_id', 'category', 'age', 'filename']]
data = data[~data['category'].isin(['something you love'])]
data.reset_index().drop(['index'], axis=1)
data['filename'] = data['filename'].apply(lambda x: x.split('/')[-1])
data['url'] = data['filename'].apply(lambda x: 'https://kiddraw.s3.amazonaws.com/' + x)
data = data.rename(columns={'category':'class'})

# add a shuffle id and a games variable to indicate the number of times the current image is labelled
data_range = np.arange(data.shape[0])
np.random.shuffle(data_range)
data['shuffler_ind'] = data_range
data['games'] = '[]'
data['games'] = data['games'].apply(lambda x: ast.literal_eval(x))

# add image url

# %%
data
# Out:
#                     session_id        class   age  \
# 0      cdm_run_v51551378173946       square  age2
# 1      cdm_run_v51551378173946  this square  age2
# 2      cdm_run_v51551378173946      a tiger  age2
# 3      cdm_run_v51551378173946     a cactus  age2
# 4      cdm_run_v51551378776163       square  age6
# 5      cdm_run_v51551378776163        shape  age6
# 6      cdm_run_v51551378776163  this square  age6
# 7      cdm_run_v51551378776163      a whale  age6
# 8      cdm_run_v51551378776163        a hat  age6
# 9      cdm_run_v51551379596662       square  age6
# 10     cdm_run_v51551379596662        shape  age6
# 11     cdm_run_v51551379596662  this square  age6
# 12     cdm_run_v51551379596662     a bottle  age6
# 13     cdm_run_v51551379596662       a lamp  age6
# 14     cdm_run_v51551379596662        a hat  age6
# 15     cdm_run_v51551379596662      a tiger  age6
# 16     cdm_run_v51551379596662      a camel  age6
# 17     cdm_run_v51551379596662     a cactus  age6
# 18     cdm_run_v51551379596662      a whale  age6
# 19     cdm_run_v51551379596662      a watch  age6
# 21     cdm_run_v51551379846475       square  age3
# 22     cdm_run_v51551379846475        shape  age3
# 23     cdm_run_v51551379846475  this square  age3
# 24     cdm_run_v51551379846475        a hat  age3
# 25     cdm_run_v51551379846475       a lamp  age3
# 26     cdm_run_v51551379846475     a cactus  age3
# 27     cdm_run_v51551379846475      a tiger  age3
# 28     cdm_run_v51551379846475      a whale  age3
# 29     cdm_run_v51551379846475     a bottle  age3
# 30     cdm_run_v51551379846475      a camel  age3
# ...                        ...          ...   ...
# 14414  cdm_run_v51560537891917      a camel  age4
# 14416  cdm_run_v51560538392618       square  age4
# 14417  cdm_run_v51560538392618        shape  age4
# 14418  cdm_run_v51560538459736       square  age8
# 14419  cdm_run_v51560538459736        shape  age8
# 14420  cdm_run_v51560538459736  this square  age8
# 14421  cdm_run_v51560538459736        a hat  age8
# 14422  cdm_run_v51560538640461       square  age8
# 14423  cdm_run_v51560538640461        shape  age8
# 14424  cdm_run_v51560538640461  this square  age8
# 14425  cdm_run_v51560538640461      a watch  age8
# 14426  cdm_run_v51560538640461       a lamp  age8
# 14427  cdm_run_v51560538640461     a cactus  age8
# 14428  cdm_run_v51560538640461      a whale  age8
# 14429  cdm_run_v51560538640461     a bottle  age8
# 14430  cdm_run_v51560538640461      a tiger  age8
# 14431  cdm_run_v51560538640461      a camel  age8
# 14432  cdm_run_v51560538640461        a hat  age8
# 14434  cdm_run_v51560539004746       square  age4
# 14435  cdm_run_v51560539054002       square  age6
# 14436  cdm_run_v51560539054002        shape  age6
# 14437  cdm_run_v51560539054002  this square  age6
# 14438  cdm_run_v51560539054002      a camel  age6
# 14439  cdm_run_v51560539054002      a whale  age6
# 14440  cdm_run_v51560539054002     a cactus  age6
# 14441  cdm_run_v51560539054002      a tiger  age6
# 14442  cdm_run_v51560539054002        a hat  age6
# 14443  cdm_run_v51560539054002      a watch  age6
# 14444  cdm_run_v51560539054002       a lamp  age6
# 14445  cdm_run_v51560539054002     a bottle  age6
#
#                                                 filename  \
# 0         square_sketch_age2_cdm_run_v51551378173946.png
# 1      this square_sketch_age2_cdm_run_v5155137817394...
# 2        a tiger_sketch_age2_cdm_run_v51551378173946.png
# 3       a cactus_sketch_age2_cdm_run_v51551378173946.png
# 4         square_sketch_age6_cdm_run_v51551378776163.png
# 5          shape_sketch_age6_cdm_run_v51551378776163.png
# 6      this square_sketch_age6_cdm_run_v5155137877616...
# 7        a whale_sketch_age6_cdm_run_v51551378776163.png
# 8          a hat_sketch_age6_cdm_run_v51551378776163.png
# 9         square_sketch_age6_cdm_run_v51551379596662.png
# 10         shape_sketch_age6_cdm_run_v51551379596662.png
# 11     this square_sketch_age6_cdm_run_v5155137959666...
# 12      a bottle_sketch_age6_cdm_run_v51551379596662.png
# 13        a lamp_sketch_age6_cdm_run_v51551379596662.png
# 14         a hat_sketch_age6_cdm_run_v51551379596662.png
# 15       a tiger_sketch_age6_cdm_run_v51551379596662.png
# 16       a camel_sketch_age6_cdm_run_v51551379596662.png
# 17      a cactus_sketch_age6_cdm_run_v51551379596662.png
# 18       a whale_sketch_age6_cdm_run_v51551379596662.png
# 19       a watch_sketch_age6_cdm_run_v51551379596662.png
# 21        square_sketch_age3_cdm_run_v51551379846475.png
# 22         shape_sketch_age3_cdm_run_v51551379846475.png
# 23     this square_sketch_age3_cdm_run_v5155137984647...
# 24         a hat_sketch_age3_cdm_run_v51551379846475.png
# 25        a lamp_sketch_age3_cdm_run_v51551379846475.png
# 26      a cactus_sketch_age3_cdm_run_v51551379846475.png
# 27       a tiger_sketch_age3_cdm_run_v51551379846475.png
# 28       a whale_sketch_age3_cdm_run_v51551379846475.png
# 29      a bottle_sketch_age3_cdm_run_v51551379846475.png
# 30       a camel_sketch_age3_cdm_run_v51551379846475.png
# ...                                                  ...
# 14414    a camel_sketch_age4_cdm_run_v51560537891917.png
# 14416     square_sketch_age4_cdm_run_v51560538392618.png
# 14417      shape_sketch_age4_cdm_run_v51560538392618.png
# 14418     square_sketch_age8_cdm_run_v51560538459736.png
# 14419      shape_sketch_age8_cdm_run_v51560538459736.png
# 14420  this square_sketch_age8_cdm_run_v5156053845973...
# 14421      a hat_sketch_age8_cdm_run_v51560538459736.png
# 14422     square_sketch_age8_cdm_run_v51560538640461.png
# 14423      shape_sketch_age8_cdm_run_v51560538640461.png
# 14424  this square_sketch_age8_cdm_run_v5156053864046...
# 14425    a watch_sketch_age8_cdm_run_v51560538640461.png
# 14426     a lamp_sketch_age8_cdm_run_v51560538640461.png
# 14427   a cactus_sketch_age8_cdm_run_v51560538640461.png
# 14428    a whale_sketch_age8_cdm_run_v51560538640461.png
# 14429   a bottle_sketch_age8_cdm_run_v51560538640461.png
# 14430    a tiger_sketch_age8_cdm_run_v51560538640461.png
# 14431    a camel_sketch_age8_cdm_run_v51560538640461.png
# 14432      a hat_sketch_age8_cdm_run_v51560538640461.png
# 14434     square_sketch_age4_cdm_run_v51560539004746.png
# 14435     square_sketch_age6_cdm_run_v51560539054002.png
# 14436      shape_sketch_age6_cdm_run_v51560539054002.png
# 14437  this square_sketch_age6_cdm_run_v5156053905400...
# 14438    a camel_sketch_age6_cdm_run_v51560539054002.png
# 14439    a whale_sketch_age6_cdm_run_v51560539054002.png
# 14440   a cactus_sketch_age6_cdm_run_v51560539054002.png
# 14441    a tiger_sketch_age6_cdm_run_v51560539054002.png
# 14442      a hat_sketch_age6_cdm_run_v51560539054002.png
# 14443    a watch_sketch_age6_cdm_run_v51560539054002.png
# 14444     a lamp_sketch_age6_cdm_run_v51560539054002.png
# 14445   a bottle_sketch_age6_cdm_run_v51560539054002.png
#
#                                                      url  shuffler_ind games
# 0      https://kiddraw.s3.amazonaws.com/square_sketch...          5256    []
# 1      https://kiddraw.s3.amazonaws.com/this square_s...         10656    []
# 2      https://kiddraw.s3.amazonaws.com/a tiger_sketc...         12750    []
# 3      https://kiddraw.s3.amazonaws.com/a cactus_sket...          6105    []
# 4      https://kiddraw.s3.amazonaws.com/square_sketch...          9225    []
# 5      https://kiddraw.s3.amazonaws.com/shape_sketch_...          2645    []
# 6      https://kiddraw.s3.amazonaws.com/this square_s...          9145    []
# 7      https://kiddraw.s3.amazonaws.com/a whale_sketc...         13661    []
# 8      https://kiddraw.s3.amazonaws.com/a hat_sketch_...         10894    []
# 9      https://kiddraw.s3.amazonaws.com/square_sketch...         11590    []
# 10     https://kiddraw.s3.amazonaws.com/shape_sketch_...          5693    []
# 11     https://kiddraw.s3.amazonaws.com/this square_s...          9802    []
# 12     https://kiddraw.s3.amazonaws.com/a bottle_sket...         13655    []
# 13     https://kiddraw.s3.amazonaws.com/a lamp_sketch...          9474    []
# 14     https://kiddraw.s3.amazonaws.com/a hat_sketch_...          7077    []
# 15     https://kiddraw.s3.amazonaws.com/a tiger_sketc...          8986    []
# 16     https://kiddraw.s3.amazonaws.com/a camel_sketc...         10933    []
# 17     https://kiddraw.s3.amazonaws.com/a cactus_sket...         12248    []
# 18     https://kiddraw.s3.amazonaws.com/a whale_sketc...         12207    []
# 19     https://kiddraw.s3.amazonaws.com/a watch_sketc...          6320    []
# 21     https://kiddraw.s3.amazonaws.com/square_sketch...          8979    []
# 22     https://kiddraw.s3.amazonaws.com/shape_sketch_...          8060    []
# 23     https://kiddraw.s3.amazonaws.com/this square_s...         11084    []
# 24     https://kiddraw.s3.amazonaws.com/a hat_sketch_...          1399    []
# 25     https://kiddraw.s3.amazonaws.com/a lamp_sketch...          4011    []
# 26     https://kiddraw.s3.amazonaws.com/a cactus_sket...          6157    []
# 27     https://kiddraw.s3.amazonaws.com/a tiger_sketc...         10261    []
# 28     https://kiddraw.s3.amazonaws.com/a whale_sketc...          6855    []
# 29     https://kiddraw.s3.amazonaws.com/a bottle_sket...          9970    []
# 30     https://kiddraw.s3.amazonaws.com/a camel_sketc...          4504    []
# ...                                                  ...           ...   ...
# 14414  https://kiddraw.s3.amazonaws.com/a camel_sketc...         10683    []
# 14416  https://kiddraw.s3.amazonaws.com/square_sketch...          3785    []
# 14417  https://kiddraw.s3.amazonaws.com/shape_sketch_...         12547    []
# 14418  https://kiddraw.s3.amazonaws.com/square_sketch...         11626    []
# 14419  https://kiddraw.s3.amazonaws.com/shape_sketch_...           617    []
# 14420  https://kiddraw.s3.amazonaws.com/this square_s...          9643    []
# 14421  https://kiddraw.s3.amazonaws.com/a hat_sketch_...         12034    []
# 14422  https://kiddraw.s3.amazonaws.com/square_sketch...          7373    []
# 14423  https://kiddraw.s3.amazonaws.com/shape_sketch_...         11657    []
# 14424  https://kiddraw.s3.amazonaws.com/this square_s...          1533    []
# 14425  https://kiddraw.s3.amazonaws.com/a watch_sketc...          8563    []
# 14426  https://kiddraw.s3.amazonaws.com/a lamp_sketch...          3554    []
# 14427  https://kiddraw.s3.amazonaws.com/a cactus_sket...         12088    []
# 14428  https://kiddraw.s3.amazonaws.com/a whale_sketc...         13279    []
# 14429  https://kiddraw.s3.amazonaws.com/a bottle_sket...          6383    []
# 14430  https://kiddraw.s3.amazonaws.com/a tiger_sketc...          4082    []
# 14431  https://kiddraw.s3.amazonaws.com/a camel_sketc...          1511    []
# 14432  https://kiddraw.s3.amazonaws.com/a hat_sketch_...           130    []
# 14434  https://kiddraw.s3.amazonaws.com/square_sketch...          4855    []
# 14435  https://kiddraw.s3.amazonaws.com/square_sketch...         13423    []
# 14436  https://kiddraw.s3.amazonaws.com/shape_sketch_...         13274    []
# 14437  https://kiddraw.s3.amazonaws.com/this square_s...         12568    []
# 14438  https://kiddraw.s3.amazonaws.com/a camel_sketc...          1241    []
# 14439  https://kiddraw.s3.amazonaws.com/a whale_sketc...          4814    []
# 14440  https://kiddraw.s3.amazonaws.com/a cactus_sket...          3584    []
# 14441  https://kiddraw.s3.amazonaws.com/a tiger_sketc...          3547    []
# 14442  https://kiddraw.s3.amazonaws.com/a hat_sketch_...          6414    []
# 14443  https://kiddraw.s3.amazonaws.com/a watch_sketc...          8527    []
# 14444  https://kiddraw.s3.amazonaws.com/a lamp_sketch...          2864    []
# 14445  https://kiddraw.s3.amazonaws.com/a bottle_sket...         11627    []
#
# [13756 rows x 7 columns]

# %% [markdown]
# #### Upload images to s3

# %%
runThis = 0
bucket_name = 'kiddraw'
path_to_png = 'cdm_v5'
if runThis:
    conn = boto3.resource('s3')
    b = conn.Bucket(bucket_name) 
    
    for folder in os.listdir(path_to_png):
        if folder not in ['.DS_Store', 'example', 'something you love']:
            for ind,im in enumerate(os.listdir(os.path.join(path_to_png, folder))):
                if im[-3:]=='png':
                    print ind, im
                    img_obj = b.Object(im)
                    img_obj.upload_file(os.path.join(path_to_png, folder, im))
                    img_obj.Acl().put(ACL='public-read')
                    clear_output(wait=True)  
print 'Done!'
# Out:
# Done!

# %%
for key in b.objects.all():
    print key.key

# %% [markdown]
# #### Convert the csv file to json and upload to mongoDB

# %%
# convert the csv file to json
import json
datajs = data.to_json(orient='records')
datajs = json.loads(datajs)

# %%
datajs
# Out:
# [{u'age': u'age2',
#   u'class': u'square',
#   u'filename': u'square_sketch_age2_cdm_run_v51551378173946.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551378173946',
#   u'shuffler_ind': 1608,
#   u'url': u'https://kiddraw.s3.amazonaws.com/square_sketch_age2_cdm_run_v51551378173946.png'},
#  {u'age': u'age2',
#   u'class': u'this square',
#   u'filename': u'this square_sketch_age2_cdm_run_v51551378173946.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551378173946',
#   u'shuffler_ind': 9502,
#   u'url': u'https://kiddraw.s3.amazonaws.com/this square_sketch_age2_cdm_run_v51551378173946.png'},
#  {u'age': u'age2',
#   u'class': u'a tiger',
#   u'filename': u'a tiger_sketch_age2_cdm_run_v51551378173946.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551378173946',
#   u'shuffler_ind': 8755,
#   u'url': u'https://kiddraw.s3.amazonaws.com/a tiger_sketch_age2_cdm_run_v51551378173946.png'},
#  {u'age': u'age2',
#   u'class': u'a cactus',
#   u'filename': u'a cactus_sketch_age2_cdm_run_v51551378173946.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551378173946',
#   u'shuffler_ind': 10798,
#   u'url': u'https://kiddraw.s3.amazonaws.com/a cactus_sketch_age2_cdm_run_v51551378173946.png'},
#  {u'age': u'age6',
#   u'class': u'square',
#   u'filename': u'square_sketch_age6_cdm_run_v51551378776163.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551378776163',
#   u'shuffler_ind': 12123,
#   u'url': u'https://kiddraw.s3.amazonaws.com/square_sketch_age6_cdm_run_v51551378776163.png'},
#  {u'age': u'age6',
#   u'class': u'shape',
#   u'filename': u'shape_sketch_age6_cdm_run_v51551378776163.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551378776163',
#   u'shuffler_ind': 421,
#   u'url': u'https://kiddraw.s3.amazonaws.com/shape_sketch_age6_cdm_run_v51551378776163.png'},
#  {u'age': u'age6',
#   u'class': u'this square',
#   u'filename': u'this square_sketch_age6_cdm_run_v51551378776163.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551378776163',
#   u'shuffler_ind': 8007,
#   u'url': u'https://kiddraw.s3.amazonaws.com/this square_sketch_age6_cdm_run_v51551378776163.png'},
#  {u'age': u'age6',
#   u'class': u'a whale',
#   u'filename': u'a whale_sketch_age6_cdm_run_v51551378776163.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551378776163',
#   u'shuffler_ind': 10878,
#   u'url': u'https://kiddraw.s3.amazonaws.com/a whale_sketch_age6_cdm_run_v51551378776163.png'},
#  {u'age': u'age6',
#   u'class': u'a hat',
#   u'filename': u'a hat_sketch_age6_cdm_run_v51551378776163.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551378776163',
#   u'shuffler_ind': 8256,
#   u'url': u'https://kiddraw.s3.amazonaws.com/a hat_sketch_age6_cdm_run_v51551378776163.png'},
#  {u'age': u'age6',
#   u'class': u'square',
#   u'filename': u'square_sketch_age6_cdm_run_v51551379596662.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551379596662',
#   u'shuffler_ind': 1372,
#   u'url': u'https://kiddraw.s3.amazonaws.com/square_sketch_age6_cdm_run_v51551379596662.png'},
#  {u'age': u'age6',
#   u'class': u'shape',
#   u'filename': u'shape_sketch_age6_cdm_run_v51551379596662.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551379596662',
#   u'shuffler_ind': 1966,
#   u'url': u'https://kiddraw.s3.amazonaws.com/shape_sketch_age6_cdm_run_v51551379596662.png'},
#  {u'age': u'age6',
#   u'class': u'this square',
#   u'filename': u'this square_sketch_age6_cdm_run_v51551379596662.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551379596662',
#   u'shuffler_ind': 9696,
#   u'url': u'https://kiddraw.s3.amazonaws.com/this square_sketch_age6_cdm_run_v51551379596662.png'},
#  {u'age': u'age6',
#   u'class': u'a bottle',
#   u'filename': u'a bottle_sketch_age6_cdm_run_v51551379596662.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551379596662',
#   u'shuffler_ind': 7317,
#   u'url': u'https://kiddraw.s3.amazonaws.com/a bottle_sketch_age6_cdm_run_v51551379596662.png'},
#  {u'age': u'age6',
#   u'class': u'a lamp',
#   u'filename': u'a lamp_sketch_age6_cdm_run_v51551379596662.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551379596662',
#   u'shuffler_ind': 1947,
#   u'url': u'https://kiddraw.s3.amazonaws.com/a lamp_sketch_age6_cdm_run_v51551379596662.png'},
#  {u'age': u'age6',
#   u'class': u'a hat',
#   u'filename': u'a hat_sketch_age6_cdm_run_v51551379596662.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551379596662',
#   u'shuffler_ind': 8328,
#   u'url': u'https://kiddraw.s3.amazonaws.com/a hat_sketch_age6_cdm_run_v51551379596662.png'},
#  {u'age': u'age6',
#   u'class': u'a tiger',
#   u'filename': u'a tiger_sketch_age6_cdm_run_v51551379596662.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551379596662',
#   u'shuffler_ind': 3197,
#   u'url': u'https://kiddraw.s3.amazonaws.com/a tiger_sketch_age6_cdm_run_v51551379596662.png'},
#  {u'age': u'age6',
#   u'class': u'a camel',
#   u'filename': u'a camel_sketch_age6_cdm_run_v51551379596662.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551379596662',
#   u'shuffler_ind': 7916,
#   u'url': u'https://kiddraw.s3.amazonaws.com/a camel_sketch_age6_cdm_run_v51551379596662.png'},
#  {u'age': u'age6',
#   u'class': u'a cactus',
#   u'filename': u'a cactus_sketch_age6_cdm_run_v51551379596662.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551379596662',
#   u'shuffler_ind': 1994,
#   u'url': u'https://kiddraw.s3.amazonaws.com/a cactus_sketch_age6_cdm_run_v51551379596662.png'},
#  {u'age': u'age6',
#   u'class': u'a whale',
#   u'filename': u'a whale_sketch_age6_cdm_run_v51551379596662.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551379596662',
#   u'shuffler_ind': 4417,
#   u'url': u'https://kiddraw.s3.amazonaws.com/a whale_sketch_age6_cdm_run_v51551379596662.png'},
#  {u'age': u'age6',
#   u'class': u'a watch',
#   u'filename': u'a watch_sketch_age6_cdm_run_v51551379596662.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551379596662',
#   u'shuffler_ind': 5043,
#   u'url': u'https://kiddraw.s3.amazonaws.com/a watch_sketch_age6_cdm_run_v51551379596662.png'},
#  {u'age': u'age3',
#   u'class': u'square',
#   u'filename': u'square_sketch_age3_cdm_run_v51551379846475.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551379846475',
#   u'shuffler_ind': 2119,
#   u'url': u'https://kiddraw.s3.amazonaws.com/square_sketch_age3_cdm_run_v51551379846475.png'},
#  {u'age': u'age3',
#   u'class': u'shape',
#   u'filename': u'shape_sketch_age3_cdm_run_v51551379846475.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551379846475',
#   u'shuffler_ind': 7748,
#   u'url': u'https://kiddraw.s3.amazonaws.com/shape_sketch_age3_cdm_run_v51551379846475.png'},
#  {u'age': u'age3',
#   u'class': u'this square',
#   u'filename': u'this square_sketch_age3_cdm_run_v51551379846475.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551379846475',
#   u'shuffler_ind': 5934,
#   u'url': u'https://kiddraw.s3.amazonaws.com/this square_sketch_age3_cdm_run_v51551379846475.png'},
#  {u'age': u'age3',
#   u'class': u'a hat',
#   u'filename': u'a hat_sketch_age3_cdm_run_v51551379846475.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551379846475',
#   u'shuffler_ind': 5906,
#   u'url': u'https://kiddraw.s3.amazonaws.com/a hat_sketch_age3_cdm_run_v51551379846475.png'},
#  {u'age': u'age3',
#   u'class': u'a lamp',
#   u'filename': u'a lamp_sketch_age3_cdm_run_v51551379846475.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551379846475',
#   u'shuffler_ind': 3345,
#   u'url': u'https://kiddraw.s3.amazonaws.com/a lamp_sketch_age3_cdm_run_v51551379846475.png'},
#  {u'age': u'age3',
#   u'class': u'a cactus',
#   u'filename': u'a cactus_sketch_age3_cdm_run_v51551379846475.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551379846475',
#   u'shuffler_ind': 4778,
#   u'url': u'https://kiddraw.s3.amazonaws.com/a cactus_sketch_age3_cdm_run_v51551379846475.png'},
#  {u'age': u'age3',
#   u'class': u'a tiger',
#   u'filename': u'a tiger_sketch_age3_cdm_run_v51551379846475.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551379846475',
#   u'shuffler_ind': 12311,
#   u'url': u'https://kiddraw.s3.amazonaws.com/a tiger_sketch_age3_cdm_run_v51551379846475.png'},
#  {u'age': u'age3',
#   u'class': u'a whale',
#   u'filename': u'a whale_sketch_age3_cdm_run_v51551379846475.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551379846475',
#   u'shuffler_ind': 10998,
#   u'url': u'https://kiddraw.s3.amazonaws.com/a whale_sketch_age3_cdm_run_v51551379846475.png'},
#  {u'age': u'age3',
#   u'class': u'a bottle',
#   u'filename': u'a bottle_sketch_age3_cdm_run_v51551379846475.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551379846475',
#   u'shuffler_ind': 8905,
#   u'url': u'https://kiddraw.s3.amazonaws.com/a bottle_sketch_age3_cdm_run_v51551379846475.png'},
#  {u'age': u'age3',
#   u'class': u'a camel',
#   u'filename': u'a camel_sketch_age3_cdm_run_v51551379846475.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551379846475',
#   u'shuffler_ind': 13298,
#   u'url': u'https://kiddraw.s3.amazonaws.com/a camel_sketch_age3_cdm_run_v51551379846475.png'},
#  {u'age': u'age3',
#   u'class': u'a watch',
#   u'filename': u'a watch_sketch_age3_cdm_run_v51551379846475.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551379846475',
#   u'shuffler_ind': 519,
#   u'url': u'https://kiddraw.s3.amazonaws.com/a watch_sketch_age3_cdm_run_v51551379846475.png'},
#  {u'age': u'age3',
#   u'class': u'square',
#   u'filename': u'square_sketch_age3_cdm_run_v51551380599198.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551380599198',
#   u'shuffler_ind': 10283,
#   u'url': u'https://kiddraw.s3.amazonaws.com/square_sketch_age3_cdm_run_v51551380599198.png'},
#  {u'age': u'age3',
#   u'class': u'shape',
#   u'filename': u'shape_sketch_age3_cdm_run_v51551380599198.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551380599198',
#   u'shuffler_ind': 5937,
#   u'url': u'https://kiddraw.s3.amazonaws.com/shape_sketch_age3_cdm_run_v51551380599198.png'},
#  {u'age': u'age3',
#   u'class': u'this square',
#   u'filename': u'this square_sketch_age3_cdm_run_v51551380599198.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551380599198',
#   u'shuffler_ind': 7542,
#   u'url': u'https://kiddraw.s3.amazonaws.com/this square_sketch_age3_cdm_run_v51551380599198.png'},
#  {u'age': u'age3',
#   u'class': u'square',
#   u'filename': u'square_sketch_age3_cdm_run_v51551380789914.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551380789914',
#   u'shuffler_ind': 2630,
#   u'url': u'https://kiddraw.s3.amazonaws.com/square_sketch_age3_cdm_run_v51551380789914.png'},
#  {u'age': u'age3',
#   u'class': u'shape',
#   u'filename': u'shape_sketch_age3_cdm_run_v51551380789914.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551380789914',
#   u'shuffler_ind': 10286,
#   u'url': u'https://kiddraw.s3.amazonaws.com/shape_sketch_age3_cdm_run_v51551380789914.png'},
#  {u'age': u'age3',
#   u'class': u'this square',
#   u'filename': u'this square_sketch_age3_cdm_run_v51551380789914.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551380789914',
#   u'shuffler_ind': 11707,
#   u'url': u'https://kiddraw.s3.amazonaws.com/this square_sketch_age3_cdm_run_v51551380789914.png'},
#  {u'age': u'age3',
#   u'class': u'a watch',
#   u'filename': u'a watch_sketch_age3_cdm_run_v51551380789914.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551380789914',
#   u'shuffler_ind': 1642,
#   u'url': u'https://kiddraw.s3.amazonaws.com/a watch_sketch_age3_cdm_run_v51551380789914.png'},
#  {u'age': u'age3',
#   u'class': u'a cactus',
#   u'filename': u'a cactus_sketch_age3_cdm_run_v51551380789914.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551380789914',
#   u'shuffler_ind': 9895,
#   u'url': u'https://kiddraw.s3.amazonaws.com/a cactus_sketch_age3_cdm_run_v51551380789914.png'},
#  {u'age': u'age3',
#   u'class': u'a hat',
#   u'filename': u'a hat_sketch_age3_cdm_run_v51551380789914.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551380789914',
#   u'shuffler_ind': 864,
#   u'url': u'https://kiddraw.s3.amazonaws.com/a hat_sketch_age3_cdm_run_v51551380789914.png'},
#  {u'age': u'age3',
#   u'class': u'a bottle',
#   u'filename': u'a bottle_sketch_age3_cdm_run_v51551380789914.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551380789914',
#   u'shuffler_ind': 12330,
#   u'url': u'https://kiddraw.s3.amazonaws.com/a bottle_sketch_age3_cdm_run_v51551380789914.png'},
#  {u'age': u'age3',
#   u'class': u'a lamp',
#   u'filename': u'a lamp_sketch_age3_cdm_run_v51551380789914.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551380789914',
#   u'shuffler_ind': 5980,
#   u'url': u'https://kiddraw.s3.amazonaws.com/a lamp_sketch_age3_cdm_run_v51551380789914.png'},
#  {u'age': u'age3',
#   u'class': u'a tiger',
#   u'filename': u'a tiger_sketch_age3_cdm_run_v51551380789914.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551380789914',
#   u'shuffler_ind': 10193,
#   u'url': u'https://kiddraw.s3.amazonaws.com/a tiger_sketch_age3_cdm_run_v51551380789914.png'},
#  {u'age': u'age3',
#   u'class': u'a camel',
#   u'filename': u'a camel_sketch_age3_cdm_run_v51551380789914.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551380789914',
#   u'shuffler_ind': 6257,
#   u'url': u'https://kiddraw.s3.amazonaws.com/a camel_sketch_age3_cdm_run_v51551380789914.png'},
#  {u'age': u'age7',
#   u'class': u'square',
#   u'filename': u'square_sketch_age7_cdm_run_v51551381097422.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551381097422',
#   u'shuffler_ind': 2826,
#   u'url': u'https://kiddraw.s3.amazonaws.com/square_sketch_age7_cdm_run_v51551381097422.png'},
#  {u'age': u'age7',
#   u'class': u'shape',
#   u'filename': u'shape_sketch_age7_cdm_run_v51551381097422.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551381097422',
#   u'shuffler_ind': 6045,
#   u'url': u'https://kiddraw.s3.amazonaws.com/shape_sketch_age7_cdm_run_v51551381097422.png'},
#  {u'age': u'age7',
#   u'class': u'this square',
#   u'filename': u'this square_sketch_age7_cdm_run_v51551381097422.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551381097422',
#   u'shuffler_ind': 10326,
#   u'url': u'https://kiddraw.s3.amazonaws.com/this square_sketch_age7_cdm_run_v51551381097422.png'},
#  {u'age': u'age7',
#   u'class': u'a tiger',
#   u'filename': u'a tiger_sketch_age7_cdm_run_v51551381097422.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551381097422',
#   u'shuffler_ind': 13333,
#   u'url': u'https://kiddraw.s3.amazonaws.com/a tiger_sketch_age7_cdm_run_v51551381097422.png'},
#  {u'age': u'age7',
#   u'class': u'a watch',
#   u'filename': u'a watch_sketch_age7_cdm_run_v51551381097422.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551381097422',
#   u'shuffler_ind': 968,
#   u'url': u'https://kiddraw.s3.amazonaws.com/a watch_sketch_age7_cdm_run_v51551381097422.png'},
#  {u'age': u'age7',
#   u'class': u'a bottle',
#   u'filename': u'a bottle_sketch_age7_cdm_run_v51551381097422.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551381097422',
#   u'shuffler_ind': 10570,
#   u'url': u'https://kiddraw.s3.amazonaws.com/a bottle_sketch_age7_cdm_run_v51551381097422.png'},
#  {u'age': u'age7',
#   u'class': u'a lamp',
#   u'filename': u'a lamp_sketch_age7_cdm_run_v51551381097422.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551381097422',
#   u'shuffler_ind': 1031,
#   u'url': u'https://kiddraw.s3.amazonaws.com/a lamp_sketch_age7_cdm_run_v51551381097422.png'},
#  {u'age': u'age7',
#   u'class': u'a camel',
#   u'filename': u'a camel_sketch_age7_cdm_run_v51551381097422.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551381097422',
#   u'shuffler_ind': 9017,
#   u'url': u'https://kiddraw.s3.amazonaws.com/a camel_sketch_age7_cdm_run_v51551381097422.png'},
#  {u'age': u'age7',
#   u'class': u'a whale',
#   u'filename': u'a whale_sketch_age7_cdm_run_v51551381097422.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551381097422',
#   u'shuffler_ind': 1523,
#   u'url': u'https://kiddraw.s3.amazonaws.com/a whale_sketch_age7_cdm_run_v51551381097422.png'},
#  {u'age': u'age7',
#   u'class': u'a cactus',
#   u'filename': u'a cactus_sketch_age7_cdm_run_v51551381097422.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551381097422',
#   u'shuffler_ind': 8236,
#   u'url': u'https://kiddraw.s3.amazonaws.com/a cactus_sketch_age7_cdm_run_v51551381097422.png'},
#  {u'age': u'age7',
#   u'class': u'square',
#   u'filename': u'square_sketch_age7_cdm_run_v51551381372446.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551381372446',
#   u'shuffler_ind': 9377,
#   u'url': u'https://kiddraw.s3.amazonaws.com/square_sketch_age7_cdm_run_v51551381372446.png'},
#  {u'age': u'age7',
#   u'class': u'shape',
#   u'filename': u'shape_sketch_age7_cdm_run_v51551381372446.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551381372446',
#   u'shuffler_ind': 2452,
#   u'url': u'https://kiddraw.s3.amazonaws.com/shape_sketch_age7_cdm_run_v51551381372446.png'},
#  {u'age': u'age7',
#   u'class': u'this square',
#   u'filename': u'this square_sketch_age7_cdm_run_v51551381372446.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551381372446',
#   u'shuffler_ind': 9122,
#   u'url': u'https://kiddraw.s3.amazonaws.com/this square_sketch_age7_cdm_run_v51551381372446.png'},
#  {u'age': u'age7',
#   u'class': u'a hat',
#   u'filename': u'a hat_sketch_age7_cdm_run_v51551381372446.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551381372446',
#   u'shuffler_ind': 5493,
#   u'url': u'https://kiddraw.s3.amazonaws.com/a hat_sketch_age7_cdm_run_v51551381372446.png'},
#  {u'age': u'age7',
#   u'class': u'a bottle',
#   u'filename': u'a bottle_sketch_age7_cdm_run_v51551381372446.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551381372446',
#   u'shuffler_ind': 7675,
#   u'url': u'https://kiddraw.s3.amazonaws.com/a bottle_sketch_age7_cdm_run_v51551381372446.png'},
#  {u'age': u'age7',
#   u'class': u'a camel',
#   u'filename': u'a camel_sketch_age7_cdm_run_v51551381372446.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551381372446',
#   u'shuffler_ind': 8616,
#   u'url': u'https://kiddraw.s3.amazonaws.com/a camel_sketch_age7_cdm_run_v51551381372446.png'},
#  {u'age': u'age7',
#   u'class': u'a whale',
#   u'filename': u'a whale_sketch_age7_cdm_run_v51551381372446.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551381372446',
#   u'shuffler_ind': 6566,
#   u'url': u'https://kiddraw.s3.amazonaws.com/a whale_sketch_age7_cdm_run_v51551381372446.png'},
#  {u'age': u'age7',
#   u'class': u'a lamp',
#   u'filename': u'a lamp_sketch_age7_cdm_run_v51551381372446.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551381372446',
#   u'shuffler_ind': 6027,
#   u'url': u'https://kiddraw.s3.amazonaws.com/a lamp_sketch_age7_cdm_run_v51551381372446.png'},
#  {u'age': u'age7',
#   u'class': u'a tiger',
#   u'filename': u'a tiger_sketch_age7_cdm_run_v51551381372446.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551381372446',
#   u'shuffler_ind': 3490,
#   u'url': u'https://kiddraw.s3.amazonaws.com/a tiger_sketch_age7_cdm_run_v51551381372446.png'},
#  {u'age': u'age7',
#   u'class': u'a cactus',
#   u'filename': u'a cactus_sketch_age7_cdm_run_v51551381372446.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551381372446',
#   u'shuffler_ind': 780,
#   u'url': u'https://kiddraw.s3.amazonaws.com/a cactus_sketch_age7_cdm_run_v51551381372446.png'},
#  {u'age': u'age7',
#   u'class': u'a watch',
#   u'filename': u'a watch_sketch_age7_cdm_run_v51551381372446.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551381372446',
#   u'shuffler_ind': 10487,
#   u'url': u'https://kiddraw.s3.amazonaws.com/a watch_sketch_age7_cdm_run_v51551381372446.png'},
#  {u'age': u'age8',
#   u'class': u'square',
#   u'filename': u'square_sketch_age8_cdm_run_v51551381627322.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551381627322',
#   u'shuffler_ind': 11035,
#   u'url': u'https://kiddraw.s3.amazonaws.com/square_sketch_age8_cdm_run_v51551381627322.png'},
#  {u'age': u'age8',
#   u'class': u'shape',
#   u'filename': u'shape_sketch_age8_cdm_run_v51551381627322.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551381627322',
#   u'shuffler_ind': 3747,
#   u'url': u'https://kiddraw.s3.amazonaws.com/shape_sketch_age8_cdm_run_v51551381627322.png'},
#  {u'age': u'age8',
#   u'class': u'this square',
#   u'filename': u'this square_sketch_age8_cdm_run_v51551381627322.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551381627322',
#   u'shuffler_ind': 4242,
#   u'url': u'https://kiddraw.s3.amazonaws.com/this square_sketch_age8_cdm_run_v51551381627322.png'},
#  {u'age': u'age8',
#   u'class': u'a tiger',
#   u'filename': u'a tiger_sketch_age8_cdm_run_v51551381627322.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551381627322',
#   u'shuffler_ind': 1724,
#   u'url': u'https://kiddraw.s3.amazonaws.com/a tiger_sketch_age8_cdm_run_v51551381627322.png'},
#  {u'age': u'age8',
#   u'class': u'a lamp',
#   u'filename': u'a lamp_sketch_age8_cdm_run_v51551381627322.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551381627322',
#   u'shuffler_ind': 3355,
#   u'url': u'https://kiddraw.s3.amazonaws.com/a lamp_sketch_age8_cdm_run_v51551381627322.png'},
#  {u'age': u'age8',
#   u'class': u'a cactus',
#   u'filename': u'a cactus_sketch_age8_cdm_run_v51551381627322.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551381627322',
#   u'shuffler_ind': 6333,
#   u'url': u'https://kiddraw.s3.amazonaws.com/a cactus_sketch_age8_cdm_run_v51551381627322.png'},
#  {u'age': u'age8',
#   u'class': u'a whale',
#   u'filename': u'a whale_sketch_age8_cdm_run_v51551381627322.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551381627322',
#   u'shuffler_ind': 5825,
#   u'url': u'https://kiddraw.s3.amazonaws.com/a whale_sketch_age8_cdm_run_v51551381627322.png'},
#  {u'age': u'age8',
#   u'class': u'a watch',
#   u'filename': u'a watch_sketch_age8_cdm_run_v51551381627322.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551381627322',
#   u'shuffler_ind': 13712,
#   u'url': u'https://kiddraw.s3.amazonaws.com/a watch_sketch_age8_cdm_run_v51551381627322.png'},
#  {u'age': u'age8',
#   u'class': u'a bottle',
#   u'filename': u'a bottle_sketch_age8_cdm_run_v51551381627322.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551381627322',
#   u'shuffler_ind': 5465,
#   u'url': u'https://kiddraw.s3.amazonaws.com/a bottle_sketch_age8_cdm_run_v51551381627322.png'},
#  {u'age': u'age8',
#   u'class': u'a hat',
#   u'filename': u'a hat_sketch_age8_cdm_run_v51551381627322.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551381627322',
#   u'shuffler_ind': 6524,
#   u'url': u'https://kiddraw.s3.amazonaws.com/a hat_sketch_age8_cdm_run_v51551381627322.png'},
#  {u'age': u'age8',
#   u'class': u'a camel',
#   u'filename': u'a camel_sketch_age8_cdm_run_v51551381627322.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551381627322',
#   u'shuffler_ind': 12801,
#   u'url': u'https://kiddraw.s3.amazonaws.com/a camel_sketch_age8_cdm_run_v51551381627322.png'},
#  {u'age': u'age2',
#   u'class': u'square',
#   u'filename': u'square_sketch_age2_cdm_run_v51551381826038.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551381826038',
#   u'shuffler_ind': 8704,
#   u'url': u'https://kiddraw.s3.amazonaws.com/square_sketch_age2_cdm_run_v51551381826038.png'},
#  {u'age': u'age2',
#   u'class': u'shape',
#   u'filename': u'shape_sketch_age2_cdm_run_v51551381826038.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551381826038',
#   u'shuffler_ind': 10636,
#   u'url': u'https://kiddraw.s3.amazonaws.com/shape_sketch_age2_cdm_run_v51551381826038.png'},
#  {u'age': u'age2',
#   u'class': u'this square',
#   u'filename': u'this square_sketch_age2_cdm_run_v51551381826038.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551381826038',
#   u'shuffler_ind': 1398,
#   u'url': u'https://kiddraw.s3.amazonaws.com/this square_sketch_age2_cdm_run_v51551381826038.png'},
#  {u'age': u'age2',
#   u'class': u'a cactus',
#   u'filename': u'a cactus_sketch_age2_cdm_run_v51551381826038.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551381826038',
#   u'shuffler_ind': 11508,
#   u'url': u'https://kiddraw.s3.amazonaws.com/a cactus_sketch_age2_cdm_run_v51551381826038.png'},
#  {u'age': u'age2',
#   u'class': u'a camel',
#   u'filename': u'a camel_sketch_age2_cdm_run_v51551381826038.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551381826038',
#   u'shuffler_ind': 8885,
#   u'url': u'https://kiddraw.s3.amazonaws.com/a camel_sketch_age2_cdm_run_v51551381826038.png'},
#  {u'age': u'age4',
#   u'class': u'shape',
#   u'filename': u'shape_sketch_age4_cdm_run_v51551382115374.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551382115374',
#   u'shuffler_ind': 13517,
#   u'url': u'https://kiddraw.s3.amazonaws.com/shape_sketch_age4_cdm_run_v51551382115374.png'},
#  {u'age': u'age4',
#   u'class': u'this square',
#   u'filename': u'this square_sketch_age4_cdm_run_v51551382115374.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551382115374',
#   u'shuffler_ind': 6939,
#   u'url': u'https://kiddraw.s3.amazonaws.com/this square_sketch_age4_cdm_run_v51551382115374.png'},
#  {u'age': u'age4',
#   u'class': u'a tiger',
#   u'filename': u'a tiger_sketch_age4_cdm_run_v51551382115374.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551382115374',
#   u'shuffler_ind': 10675,
#   u'url': u'https://kiddraw.s3.amazonaws.com/a tiger_sketch_age4_cdm_run_v51551382115374.png'},
#  {u'age': u'age4',
#   u'class': u'a camel',
#   u'filename': u'a camel_sketch_age4_cdm_run_v51551382115374.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551382115374',
#   u'shuffler_ind': 13164,
#   u'url': u'https://kiddraw.s3.amazonaws.com/a camel_sketch_age4_cdm_run_v51551382115374.png'},
#  {u'age': u'age4',
#   u'class': u'a whale',
#   u'filename': u'a whale_sketch_age4_cdm_run_v51551382115374.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551382115374',
#   u'shuffler_ind': 12543,
#   u'url': u'https://kiddraw.s3.amazonaws.com/a whale_sketch_age4_cdm_run_v51551382115374.png'},
#  {u'age': u'age4',
#   u'class': u'a cactus',
#   u'filename': u'a cactus_sketch_age4_cdm_run_v51551382115374.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551382115374',
#   u'shuffler_ind': 12542,
#   u'url': u'https://kiddraw.s3.amazonaws.com/a cactus_sketch_age4_cdm_run_v51551382115374.png'},
#  {u'age': u'age4',
#   u'class': u'a lamp',
#   u'filename': u'a lamp_sketch_age4_cdm_run_v51551382115374.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551382115374',
#   u'shuffler_ind': 1053,
#   u'url': u'https://kiddraw.s3.amazonaws.com/a lamp_sketch_age4_cdm_run_v51551382115374.png'},
#  {u'age': u'age7',
#   u'class': u'square',
#   u'filename': u'square_sketch_age7_cdm_run_v51551383573763.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551383573763',
#   u'shuffler_ind': 10061,
#   u'url': u'https://kiddraw.s3.amazonaws.com/square_sketch_age7_cdm_run_v51551383573763.png'},
#  {u'age': u'age7',
#   u'class': u'shape',
#   u'filename': u'shape_sketch_age7_cdm_run_v51551383573763.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551383573763',
#   u'shuffler_ind': 7940,
#   u'url': u'https://kiddraw.s3.amazonaws.com/shape_sketch_age7_cdm_run_v51551383573763.png'},
#  {u'age': u'age7',
#   u'class': u'this square',
#   u'filename': u'this square_sketch_age7_cdm_run_v51551383573763.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551383573763',
#   u'shuffler_ind': 12409,
#   u'url': u'https://kiddraw.s3.amazonaws.com/this square_sketch_age7_cdm_run_v51551383573763.png'},
#  {u'age': u'age7',
#   u'class': u'a tiger',
#   u'filename': u'a tiger_sketch_age7_cdm_run_v51551383573763.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551383573763',
#   u'shuffler_ind': 1511,
#   u'url': u'https://kiddraw.s3.amazonaws.com/a tiger_sketch_age7_cdm_run_v51551383573763.png'},
#  {u'age': u'age8',
#   u'class': u'square',
#   u'filename': u'square_sketch_age8_cdm_run_v51551383733410.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551383733410',
#   u'shuffler_ind': 6127,
#   u'url': u'https://kiddraw.s3.amazonaws.com/square_sketch_age8_cdm_run_v51551383733410.png'},
#  {u'age': u'age8',
#   u'class': u'shape',
#   u'filename': u'shape_sketch_age8_cdm_run_v51551383733410.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551383733410',
#   u'shuffler_ind': 6366,
#   u'url': u'https://kiddraw.s3.amazonaws.com/shape_sketch_age8_cdm_run_v51551383733410.png'},
#  {u'age': u'age8',
#   u'class': u'this square',
#   u'filename': u'this square_sketch_age8_cdm_run_v51551383733410.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551383733410',
#   u'shuffler_ind': 12754,
#   u'url': u'https://kiddraw.s3.amazonaws.com/this square_sketch_age8_cdm_run_v51551383733410.png'},
#  {u'age': u'age8',
#   u'class': u'a tiger',
#   u'filename': u'a tiger_sketch_age8_cdm_run_v51551383733410.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551383733410',
#   u'shuffler_ind': 13168,
#   u'url': u'https://kiddraw.s3.amazonaws.com/a tiger_sketch_age8_cdm_run_v51551383733410.png'},
#  {u'age': u'age8',
#   u'class': u'a whale',
#   u'filename': u'a whale_sketch_age8_cdm_run_v51551383733410.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551383733410',
#   u'shuffler_ind': 3201,
#   u'url': u'https://kiddraw.s3.amazonaws.com/a whale_sketch_age8_cdm_run_v51551383733410.png'},
#  {u'age': u'age8',
#   u'class': u'a bottle',
#   u'filename': u'a bottle_sketch_age8_cdm_run_v51551383733410.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551383733410',
#   u'shuffler_ind': 6396,
#   u'url': u'https://kiddraw.s3.amazonaws.com/a bottle_sketch_age8_cdm_run_v51551383733410.png'},
#  {u'age': u'age8',
#   u'class': u'a lamp',
#   u'filename': u'a lamp_sketch_age8_cdm_run_v51551383733410.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551383733410',
#   u'shuffler_ind': 7110,
#   u'url': u'https://kiddraw.s3.amazonaws.com/a lamp_sketch_age8_cdm_run_v51551383733410.png'},
#  {u'age': u'age8',
#   u'class': u'a camel',
#   u'filename': u'a camel_sketch_age8_cdm_run_v51551383733410.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551383733410',
#   u'shuffler_ind': 13676,
#   u'url': u'https://kiddraw.s3.amazonaws.com/a camel_sketch_age8_cdm_run_v51551383733410.png'},
#  {u'age': u'age8',
#   u'class': u'a hat',
#   u'filename': u'a hat_sketch_age8_cdm_run_v51551383733410.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551383733410',
#   u'shuffler_ind': 12262,
#   u'url': u'https://kiddraw.s3.amazonaws.com/a hat_sketch_age8_cdm_run_v51551383733410.png'},
#  {u'age': u'age8',
#   u'class': u'a watch',
#   u'filename': u'a watch_sketch_age8_cdm_run_v51551383733410.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551383733410',
#   u'shuffler_ind': 10090,
#   u'url': u'https://kiddraw.s3.amazonaws.com/a watch_sketch_age8_cdm_run_v51551383733410.png'},
#  {u'age': u'age8',
#   u'class': u'a cactus',
#   u'filename': u'a cactus_sketch_age8_cdm_run_v51551383733410.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551383733410',
#   u'shuffler_ind': 11830,
#   u'url': u'https://kiddraw.s3.amazonaws.com/a cactus_sketch_age8_cdm_run_v51551383733410.png'},
#  {u'age': u'age3',
#   u'class': u'square',
#   u'filename': u'square_sketch_age3_cdm_run_v51551384006504.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551384006504',
#   u'shuffler_ind': 7067,
#   u'url': u'https://kiddraw.s3.amazonaws.com/square_sketch_age3_cdm_run_v51551384006504.png'},
#  {u'age': u'age3',
#   u'class': u'shape',
#   u'filename': u'shape_sketch_age3_cdm_run_v51551384006504.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551384006504',
#   u'shuffler_ind': 2634,
#   u'url': u'https://kiddraw.s3.amazonaws.com/shape_sketch_age3_cdm_run_v51551384006504.png'},
#  {u'age': u'age7',
#   u'class': u'square',
#   u'filename': u'square_sketch_age7_cdm_run_v51551384706708.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551384706708',
#   u'shuffler_ind': 5102,
#   u'url': u'https://kiddraw.s3.amazonaws.com/square_sketch_age7_cdm_run_v51551384706708.png'},
#  {u'age': u'age7',
#   u'class': u'shape',
#   u'filename': u'shape_sketch_age7_cdm_run_v51551384706708.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551384706708',
#   u'shuffler_ind': 6258,
#   u'url': u'https://kiddraw.s3.amazonaws.com/shape_sketch_age7_cdm_run_v51551384706708.png'},
#  {u'age': u'age7',
#   u'class': u'this square',
#   u'filename': u'this square_sketch_age7_cdm_run_v51551384706708.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551384706708',
#   u'shuffler_ind': 2894,
#   u'url': u'https://kiddraw.s3.amazonaws.com/this square_sketch_age7_cdm_run_v51551384706708.png'},
#  {u'age': u'age7',
#   u'class': u'a watch',
#   u'filename': u'a watch_sketch_age7_cdm_run_v51551384706708.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551384706708',
#   u'shuffler_ind': 10462,
#   u'url': u'https://kiddraw.s3.amazonaws.com/a watch_sketch_age7_cdm_run_v51551384706708.png'},
#  {u'age': u'age7',
#   u'class': u'a cactus',
#   u'filename': u'a cactus_sketch_age7_cdm_run_v51551384706708.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551384706708',
#   u'shuffler_ind': 6932,
#   u'url': u'https://kiddraw.s3.amazonaws.com/a cactus_sketch_age7_cdm_run_v51551384706708.png'},
#  {u'age': u'age7',
#   u'class': u'a bottle',
#   u'filename': u'a bottle_sketch_age7_cdm_run_v51551384706708.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551384706708',
#   u'shuffler_ind': 11229,
#   u'url': u'https://kiddraw.s3.amazonaws.com/a bottle_sketch_age7_cdm_run_v51551384706708.png'},
#  {u'age': u'age7',
#   u'class': u'a whale',
#   u'filename': u'a whale_sketch_age7_cdm_run_v51551384706708.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551384706708',
#   u'shuffler_ind': 6123,
#   u'url': u'https://kiddraw.s3.amazonaws.com/a whale_sketch_age7_cdm_run_v51551384706708.png'},
#  {u'age': u'age7',
#   u'class': u'a hat',
#   u'filename': u'a hat_sketch_age7_cdm_run_v51551384706708.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551384706708',
#   u'shuffler_ind': 13729,
#   u'url': u'https://kiddraw.s3.amazonaws.com/a hat_sketch_age7_cdm_run_v51551384706708.png'},
#  {u'age': u'age7',
#   u'class': u'a lamp',
#   u'filename': u'a lamp_sketch_age7_cdm_run_v51551384706708.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551384706708',
#   u'shuffler_ind': 5048,
#   u'url': u'https://kiddraw.s3.amazonaws.com/a lamp_sketch_age7_cdm_run_v51551384706708.png'},
#  {u'age': u'age7',
#   u'class': u'a camel',
#   u'filename': u'a camel_sketch_age7_cdm_run_v51551384706708.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551384706708',
#   u'shuffler_ind': 235,
#   u'url': u'https://kiddraw.s3.amazonaws.com/a camel_sketch_age7_cdm_run_v51551384706708.png'},
#  {u'age': u'age7',
#   u'class': u'a tiger',
#   u'filename': u'a tiger_sketch_age7_cdm_run_v51551384706708.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551384706708',
#   u'shuffler_ind': 1469,
#   u'url': u'https://kiddraw.s3.amazonaws.com/a tiger_sketch_age7_cdm_run_v51551384706708.png'},
#  {u'age': u'age7',
#   u'class': u'square',
#   u'filename': u'square_sketch_age7_cdm_run_v51551385448925.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551385448925',
#   u'shuffler_ind': 131,
#   u'url': u'https://kiddraw.s3.amazonaws.com/square_sketch_age7_cdm_run_v51551385448925.png'},
#  {u'age': u'age7',
#   u'class': u'shape',
#   u'filename': u'shape_sketch_age7_cdm_run_v51551385448925.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551385448925',
#   u'shuffler_ind': 2589,
#   u'url': u'https://kiddraw.s3.amazonaws.com/shape_sketch_age7_cdm_run_v51551385448925.png'},
#  {u'age': u'age7',
#   u'class': u'this square',
#   u'filename': u'this square_sketch_age7_cdm_run_v51551385448925.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551385448925',
#   u'shuffler_ind': 4249,
#   u'url': u'https://kiddraw.s3.amazonaws.com/this square_sketch_age7_cdm_run_v51551385448925.png'},
#  {u'age': u'age7',
#   u'class': u'a lamp',
#   u'filename': u'a lamp_sketch_age7_cdm_run_v51551385448925.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551385448925',
#   u'shuffler_ind': 8071,
#   u'url': u'https://kiddraw.s3.amazonaws.com/a lamp_sketch_age7_cdm_run_v51551385448925.png'},
#  {u'age': u'age6',
#   u'class': u'square',
#   u'filename': u'square_sketch_age6_cdm_run_v51551395186273.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551395186273',
#   u'shuffler_ind': 7962,
#   u'url': u'https://kiddraw.s3.amazonaws.com/square_sketch_age6_cdm_run_v51551395186273.png'},
#  {u'age': u'age6',
#   u'class': u'shape',
#   u'filename': u'shape_sketch_age6_cdm_run_v51551395186273.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551395186273',
#   u'shuffler_ind': 13158,
#   u'url': u'https://kiddraw.s3.amazonaws.com/shape_sketch_age6_cdm_run_v51551395186273.png'},
#  {u'age': u'age6',
#   u'class': u'this square',
#   u'filename': u'this square_sketch_age6_cdm_run_v51551395186273.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551395186273',
#   u'shuffler_ind': 11911,
#   u'url': u'https://kiddraw.s3.amazonaws.com/this square_sketch_age6_cdm_run_v51551395186273.png'},
#  {u'age': u'age6',
#   u'class': u'a tiger',
#   u'filename': u'a tiger_sketch_age6_cdm_run_v51551395186273.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551395186273',
#   u'shuffler_ind': 8255,
#   u'url': u'https://kiddraw.s3.amazonaws.com/a tiger_sketch_age6_cdm_run_v51551395186273.png'},
#  {u'age': u'age6',
#   u'class': u'a whale',
#   u'filename': u'a whale_sketch_age6_cdm_run_v51551395186273.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551395186273',
#   u'shuffler_ind': 12819,
#   u'url': u'https://kiddraw.s3.amazonaws.com/a whale_sketch_age6_cdm_run_v51551395186273.png'},
#  {u'age': u'age6',
#   u'class': u'a hat',
#   u'filename': u'a hat_sketch_age6_cdm_run_v51551395186273.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551395186273',
#   u'shuffler_ind': 9071,
#   u'url': u'https://kiddraw.s3.amazonaws.com/a hat_sketch_age6_cdm_run_v51551395186273.png'},
#  {u'age': u'age6',
#   u'class': u'a watch',
#   u'filename': u'a watch_sketch_age6_cdm_run_v51551395186273.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551395186273',
#   u'shuffler_ind': 2612,
#   u'url': u'https://kiddraw.s3.amazonaws.com/a watch_sketch_age6_cdm_run_v51551395186273.png'},
#  {u'age': u'age6',
#   u'class': u'a lamp',
#   u'filename': u'a lamp_sketch_age6_cdm_run_v51551395186273.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551395186273',
#   u'shuffler_ind': 9453,
#   u'url': u'https://kiddraw.s3.amazonaws.com/a lamp_sketch_age6_cdm_run_v51551395186273.png'},
#  {u'age': u'age6',
#   u'class': u'a cactus',
#   u'filename': u'a cactus_sketch_age6_cdm_run_v51551395186273.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551395186273',
#   u'shuffler_ind': 9922,
#   u'url': u'https://kiddraw.s3.amazonaws.com/a cactus_sketch_age6_cdm_run_v51551395186273.png'},
#  {u'age': u'age6',
#   u'class': u'a camel',
#   u'filename': u'a camel_sketch_age6_cdm_run_v51551395186273.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551395186273',
#   u'shuffler_ind': 11758,
#   u'url': u'https://kiddraw.s3.amazonaws.com/a camel_sketch_age6_cdm_run_v51551395186273.png'},
#  {u'age': u'age6',
#   u'class': u'a bottle',
#   u'filename': u'a bottle_sketch_age6_cdm_run_v51551395186273.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551395186273',
#   u'shuffler_ind': 8699,
#   u'url': u'https://kiddraw.s3.amazonaws.com/a bottle_sketch_age6_cdm_run_v51551395186273.png'},
#  {u'age': u'age6',
#   u'class': u'square',
#   u'filename': u'square_sketch_age6_cdm_run_v51551395480856.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551395480856',
#   u'shuffler_ind': 7098,
#   u'url': u'https://kiddraw.s3.amazonaws.com/square_sketch_age6_cdm_run_v51551395480856.png'},
#  {u'age': u'age3',
#   u'class': u'square',
#   u'filename': u'square_sketch_age3_cdm_run_v51551395574723.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551395574723',
#   u'shuffler_ind': 905,
#   u'url': u'https://kiddraw.s3.amazonaws.com/square_sketch_age3_cdm_run_v51551395574723.png'},
#  {u'age': u'age3',
#   u'class': u'shape',
#   u'filename': u'shape_sketch_age3_cdm_run_v51551395574723.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551395574723',
#   u'shuffler_ind': 8405,
#   u'url': u'https://kiddraw.s3.amazonaws.com/shape_sketch_age3_cdm_run_v51551395574723.png'},
#  {u'age': u'age3',
#   u'class': u'this square',
#   u'filename': u'this square_sketch_age3_cdm_run_v51551395574723.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551395574723',
#   u'shuffler_ind': 3753,
#   u'url': u'https://kiddraw.s3.amazonaws.com/this square_sketch_age3_cdm_run_v51551395574723.png'},
#  {u'age': u'age3',
#   u'class': u'a lamp',
#   u'filename': u'a lamp_sketch_age3_cdm_run_v51551395574723.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551395574723',
#   u'shuffler_ind': 10412,
#   u'url': u'https://kiddraw.s3.amazonaws.com/a lamp_sketch_age3_cdm_run_v51551395574723.png'},
#  {u'age': u'age3',
#   u'class': u'a cactus',
#   u'filename': u'a cactus_sketch_age3_cdm_run_v51551395574723.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551395574723',
#   u'shuffler_ind': 8913,
#   u'url': u'https://kiddraw.s3.amazonaws.com/a cactus_sketch_age3_cdm_run_v51551395574723.png'},
#  {u'age': u'age3',
#   u'class': u'a hat',
#   u'filename': u'a hat_sketch_age3_cdm_run_v51551395574723.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551395574723',
#   u'shuffler_ind': 9234,
#   u'url': u'https://kiddraw.s3.amazonaws.com/a hat_sketch_age3_cdm_run_v51551395574723.png'},
#  {u'age': u'age3',
#   u'class': u'a tiger',
#   u'filename': u'a tiger_sketch_age3_cdm_run_v51551395574723.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551395574723',
#   u'shuffler_ind': 11898,
#   u'url': u'https://kiddraw.s3.amazonaws.com/a tiger_sketch_age3_cdm_run_v51551395574723.png'},
#  {u'age': u'age10',
#   u'class': u'square',
#   u'filename': u'square_sketch_age10_cdm_run_v51551396540391.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551396540391',
#   u'shuffler_ind': 6719,
#   u'url': u'https://kiddraw.s3.amazonaws.com/square_sketch_age10_cdm_run_v51551396540391.png'},
#  {u'age': u'age10',
#   u'class': u'shape',
#   u'filename': u'shape_sketch_age10_cdm_run_v51551396540391.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551396540391',
#   u'shuffler_ind': 9640,
#   u'url': u'https://kiddraw.s3.amazonaws.com/shape_sketch_age10_cdm_run_v51551396540391.png'},
#  {u'age': u'age2',
#   u'class': u'square',
#   u'filename': u'square_sketch_age2_cdm_run_v51551465692087.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551465692087',
#   u'shuffler_ind': 6732,
#   u'url': u'https://kiddraw.s3.amazonaws.com/square_sketch_age2_cdm_run_v51551465692087.png'},
#  {u'age': u'age2',
#   u'class': u'this square',
#   u'filename': u'this square_sketch_age2_cdm_run_v51551465692087.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551465692087',
#   u'shuffler_ind': 1304,
#   u'url': u'https://kiddraw.s3.amazonaws.com/this square_sketch_age2_cdm_run_v51551465692087.png'},
#  {u'age': u'age2',
#   u'class': u'a tiger',
#   u'filename': u'a tiger_sketch_age2_cdm_run_v51551465692087.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551465692087',
#   u'shuffler_ind': 5647,
#   u'url': u'https://kiddraw.s3.amazonaws.com/a tiger_sketch_age2_cdm_run_v51551465692087.png'},
#  {u'age': u'age2',
#   u'class': u'a lamp',
#   u'filename': u'a lamp_sketch_age2_cdm_run_v51551465692087.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551465692087',
#   u'shuffler_ind': 5359,
#   u'url': u'https://kiddraw.s3.amazonaws.com/a lamp_sketch_age2_cdm_run_v51551465692087.png'},
#  {u'age': u'age2',
#   u'class': u'a bottle',
#   u'filename': u'a bottle_sketch_age2_cdm_run_v51551465692087.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551465692087',
#   u'shuffler_ind': 297,
#   u'url': u'https://kiddraw.s3.amazonaws.com/a bottle_sketch_age2_cdm_run_v51551465692087.png'},
#  {u'age': u'age2',
#   u'class': u'a camel',
#   u'filename': u'a camel_sketch_age2_cdm_run_v51551465692087.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551465692087',
#   u'shuffler_ind': 3314,
#   u'url': u'https://kiddraw.s3.amazonaws.com/a camel_sketch_age2_cdm_run_v51551465692087.png'},
#  {u'age': u'age2',
#   u'class': u'a watch',
#   u'filename': u'a watch_sketch_age2_cdm_run_v51551465692087.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551465692087',
#   u'shuffler_ind': 9011,
#   u'url': u'https://kiddraw.s3.amazonaws.com/a watch_sketch_age2_cdm_run_v51551465692087.png'},
#  {u'age': u'age2',
#   u'class': u'square',
#   u'filename': u'square_sketch_age2_cdm_run_v51551466245952.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551466245952',
#   u'shuffler_ind': 6416,
#   u'url': u'https://kiddraw.s3.amazonaws.com/square_sketch_age2_cdm_run_v51551466245952.png'},
#  {u'age': u'age2',
#   u'class': u'shape',
#   u'filename': u'shape_sketch_age2_cdm_run_v51551466245952.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551466245952',
#   u'shuffler_ind': 674,
#   u'url': u'https://kiddraw.s3.amazonaws.com/shape_sketch_age2_cdm_run_v51551466245952.png'},
#  {u'age': u'age2',
#   u'class': u'this square',
#   u'filename': u'this square_sketch_age2_cdm_run_v51551466245952.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551466245952',
#   u'shuffler_ind': 2322,
#   u'url': u'https://kiddraw.s3.amazonaws.com/this square_sketch_age2_cdm_run_v51551466245952.png'},
#  {u'age': u'age2',
#   u'class': u'square',
#   u'filename': u'square_sketch_age2_cdm_run_v51551466583535.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551466583535',
#   u'shuffler_ind': 9667,
#   u'url': u'https://kiddraw.s3.amazonaws.com/square_sketch_age2_cdm_run_v51551466583535.png'},
#  {u'age': u'age2',
#   u'class': u'shape',
#   u'filename': u'shape_sketch_age2_cdm_run_v51551466583535.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551466583535',
#   u'shuffler_ind': 12983,
#   u'url': u'https://kiddraw.s3.amazonaws.com/shape_sketch_age2_cdm_run_v51551466583535.png'},
#  {u'age': u'age2',
#   u'class': u'this square',
#   u'filename': u'this square_sketch_age2_cdm_run_v51551466583535.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551466583535',
#   u'shuffler_ind': 3528,
#   u'url': u'https://kiddraw.s3.amazonaws.com/this square_sketch_age2_cdm_run_v51551466583535.png'},
#  {u'age': u'age2',
#   u'class': u'a cactus',
#   u'filename': u'a cactus_sketch_age2_cdm_run_v51551466583535.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551466583535',
#   u'shuffler_ind': 9391,
#   u'url': u'https://kiddraw.s3.amazonaws.com/a cactus_sketch_age2_cdm_run_v51551466583535.png'},
#  {u'age': u'age2',
#   u'class': u'a hat',
#   u'filename': u'a hat_sketch_age2_cdm_run_v51551466583535.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551466583535',
#   u'shuffler_ind': 12016,
#   u'url': u'https://kiddraw.s3.amazonaws.com/a hat_sketch_age2_cdm_run_v51551466583535.png'},
#  {u'age': u'age2',
#   u'class': u'a camel',
#   u'filename': u'a camel_sketch_age2_cdm_run_v51551466583535.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551466583535',
#   u'shuffler_ind': 13692,
#   u'url': u'https://kiddraw.s3.amazonaws.com/a camel_sketch_age2_cdm_run_v51551466583535.png'},
#  {u'age': u'age2',
#   u'class': u'a bottle',
#   u'filename': u'a bottle_sketch_age2_cdm_run_v51551466583535.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551466583535',
#   u'shuffler_ind': 1550,
#   u'url': u'https://kiddraw.s3.amazonaws.com/a bottle_sketch_age2_cdm_run_v51551466583535.png'},
#  {u'age': u'age2',
#   u'class': u'a tiger',
#   u'filename': u'a tiger_sketch_age2_cdm_run_v51551466583535.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551466583535',
#   u'shuffler_ind': 6771,
#   u'url': u'https://kiddraw.s3.amazonaws.com/a tiger_sketch_age2_cdm_run_v51551466583535.png'},
#  {u'age': u'age6',
#   u'class': u'square',
#   u'filename': u'square_sketch_age6_cdm_run_v51551467354808.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551467354808',
#   u'shuffler_ind': 9452,
#   u'url': u'https://kiddraw.s3.amazonaws.com/square_sketch_age6_cdm_run_v51551467354808.png'},
#  {u'age': u'age6',
#   u'class': u'shape',
#   u'filename': u'shape_sketch_age6_cdm_run_v51551467354808.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551467354808',
#   u'shuffler_ind': 12951,
#   u'url': u'https://kiddraw.s3.amazonaws.com/shape_sketch_age6_cdm_run_v51551467354808.png'},
#  {u'age': u'age6',
#   u'class': u'this square',
#   u'filename': u'this square_sketch_age6_cdm_run_v51551467354808.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551467354808',
#   u'shuffler_ind': 7636,
#   u'url': u'https://kiddraw.s3.amazonaws.com/this square_sketch_age6_cdm_run_v51551467354808.png'},
#  {u'age': u'age3',
#   u'class': u'square',
#   u'filename': u'square_sketch_age3_cdm_run_v51551467671452.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551467671452',
#   u'shuffler_ind': 9666,
#   u'url': u'https://kiddraw.s3.amazonaws.com/square_sketch_age3_cdm_run_v51551467671452.png'},
#  {u'age': u'age3',
#   u'class': u'shape',
#   u'filename': u'shape_sketch_age3_cdm_run_v51551467671452.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551467671452',
#   u'shuffler_ind': 7420,
#   u'url': u'https://kiddraw.s3.amazonaws.com/shape_sketch_age3_cdm_run_v51551467671452.png'},
#  {u'age': u'age3',
#   u'class': u'this square',
# ...
#   u'games': [],
#   u'session_id': u'cdm_run_v51551649335149',
#   u'shuffler_ind': 11951,
#   u'url': u'https://kiddraw.s3.amazonaws.com/a tiger_sketch_age2_cdm_run_v51551649335149.png'},
#  {u'age': u'age7',
#   u'class': u'square',
#   u'filename': u'square_sketch_age7_cdm_run_v51551649719944.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551649719944',
#   u'shuffler_ind': 1374,
#   u'url': u'https://kiddraw.s3.amazonaws.com/square_sketch_age7_cdm_run_v51551649719944.png'},
#  {u'age': u'age7',
#   u'class': u'shape',
#   u'filename': u'shape_sketch_age7_cdm_run_v51551649719944.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551649719944',
#   u'shuffler_ind': 4088,
#   u'url': u'https://kiddraw.s3.amazonaws.com/shape_sketch_age7_cdm_run_v51551649719944.png'},
#  {u'age': u'age7',
#   u'class': u'this square',
#   u'filename': u'this square_sketch_age7_cdm_run_v51551649719944.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551649719944',
#   u'shuffler_ind': 3525,
#   u'url': u'https://kiddraw.s3.amazonaws.com/this square_sketch_age7_cdm_run_v51551649719944.png'},
#  {u'age': u'age7',
#   u'class': u'a cactus',
#   u'filename': u'a cactus_sketch_age7_cdm_run_v51551649719944.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551649719944',
#   u'shuffler_ind': 1033,
#   u'url': u'https://kiddraw.s3.amazonaws.com/a cactus_sketch_age7_cdm_run_v51551649719944.png'},
#  {u'age': u'age7',
#   u'class': u'a whale',
#   u'filename': u'a whale_sketch_age7_cdm_run_v51551649719944.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551649719944',
#   u'shuffler_ind': 9027,
#   u'url': u'https://kiddraw.s3.amazonaws.com/a whale_sketch_age7_cdm_run_v51551649719944.png'},
#  {u'age': u'age7',
#   u'class': u'a watch',
#   u'filename': u'a watch_sketch_age7_cdm_run_v51551649719944.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551649719944',
#   u'shuffler_ind': 11000,
#   u'url': u'https://kiddraw.s3.amazonaws.com/a watch_sketch_age7_cdm_run_v51551649719944.png'},
#  {u'age': u'age7',
#   u'class': u'a bottle',
#   u'filename': u'a bottle_sketch_age7_cdm_run_v51551649719944.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551649719944',
#   u'shuffler_ind': 10749,
#   u'url': u'https://kiddraw.s3.amazonaws.com/a bottle_sketch_age7_cdm_run_v51551649719944.png'},
#  {u'age': u'age7',
#   u'class': u'a tiger',
#   u'filename': u'a tiger_sketch_age7_cdm_run_v51551649719944.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551649719944',
#   u'shuffler_ind': 4595,
#   u'url': u'https://kiddraw.s3.amazonaws.com/a tiger_sketch_age7_cdm_run_v51551649719944.png'},
#  {u'age': u'age2',
#   u'class': u'square',
#   u'filename': u'square_sketch_age2_cdm_run_v51551649920481.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551649920481',
#   u'shuffler_ind': 7509,
#   u'url': u'https://kiddraw.s3.amazonaws.com/square_sketch_age2_cdm_run_v51551649920481.png'},
#  {u'age': u'age2',
#   u'class': u'shape',
#   u'filename': u'shape_sketch_age2_cdm_run_v51551649920481.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551649920481',
#   u'shuffler_ind': 8116,
#   u'url': u'https://kiddraw.s3.amazonaws.com/shape_sketch_age2_cdm_run_v51551649920481.png'},
#  {u'age': u'age2',
#   u'class': u'this square',
#   u'filename': u'this square_sketch_age2_cdm_run_v51551649920481.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551649920481',
#   u'shuffler_ind': 95,
#   u'url': u'https://kiddraw.s3.amazonaws.com/this square_sketch_age2_cdm_run_v51551649920481.png'},
#  {u'age': u'age4',
#   u'class': u'square',
#   u'filename': u'square_sketch_age4_cdm_run_v51551649983525.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551649983525',
#   u'shuffler_ind': 229,
#   u'url': u'https://kiddraw.s3.amazonaws.com/square_sketch_age4_cdm_run_v51551649983525.png'},
#  {u'age': u'age4',
#   u'class': u'shape',
#   u'filename': u'shape_sketch_age4_cdm_run_v51551649983525.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551649983525',
#   u'shuffler_ind': 9723,
#   u'url': u'https://kiddraw.s3.amazonaws.com/shape_sketch_age4_cdm_run_v51551649983525.png'},
#  {u'age': u'age4',
#   u'class': u'this square',
#   u'filename': u'this square_sketch_age4_cdm_run_v51551649983525.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551649983525',
#   u'shuffler_ind': 8458,
#   u'url': u'https://kiddraw.s3.amazonaws.com/this square_sketch_age4_cdm_run_v51551649983525.png'},
#  {u'age': u'age6',
#   u'class': u'square',
#   u'filename': u'square_sketch_age6_cdm_run_v51551650104505.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551650104505',
#   u'shuffler_ind': 8106,
#   u'url': u'https://kiddraw.s3.amazonaws.com/square_sketch_age6_cdm_run_v51551650104505.png'},
#  {u'age': u'age6',
#   u'class': u'shape',
#   u'filename': u'shape_sketch_age6_cdm_run_v51551650104505.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551650104505',
#   u'shuffler_ind': 3826,
#   u'url': u'https://kiddraw.s3.amazonaws.com/shape_sketch_age6_cdm_run_v51551650104505.png'},
#  {u'age': u'age6',
#   u'class': u'this square',
#   u'filename': u'this square_sketch_age6_cdm_run_v51551650104505.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551650104505',
#   u'shuffler_ind': 10649,
#   u'url': u'https://kiddraw.s3.amazonaws.com/this square_sketch_age6_cdm_run_v51551650104505.png'},
#  {u'age': u'age6',
#   u'class': u'a tiger',
#   u'filename': u'a tiger_sketch_age6_cdm_run_v51551650104505.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551650104505',
#   u'shuffler_ind': 7012,
#   u'url': u'https://kiddraw.s3.amazonaws.com/a tiger_sketch_age6_cdm_run_v51551650104505.png'},
#  {u'age': u'age6',
#   u'class': u'a whale',
#   u'filename': u'a whale_sketch_age6_cdm_run_v51551650104505.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551650104505',
#   u'shuffler_ind': 3160,
#   u'url': u'https://kiddraw.s3.amazonaws.com/a whale_sketch_age6_cdm_run_v51551650104505.png'},
#  {u'age': u'age6',
#   u'class': u'a cactus',
#   u'filename': u'a cactus_sketch_age6_cdm_run_v51551650104505.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551650104505',
#   u'shuffler_ind': 10027,
#   u'url': u'https://kiddraw.s3.amazonaws.com/a cactus_sketch_age6_cdm_run_v51551650104505.png'},
#  {u'age': u'age6',
#   u'class': u'a watch',
#   u'filename': u'a watch_sketch_age6_cdm_run_v51551650104505.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551650104505',
#   u'shuffler_ind': 6687,
#   u'url': u'https://kiddraw.s3.amazonaws.com/a watch_sketch_age6_cdm_run_v51551650104505.png'},
#  {u'age': u'age6',
#   u'class': u'a lamp',
#   u'filename': u'a lamp_sketch_age6_cdm_run_v51551650104505.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551650104505',
#   u'shuffler_ind': 13559,
#   u'url': u'https://kiddraw.s3.amazonaws.com/a lamp_sketch_age6_cdm_run_v51551650104505.png'},
#  {u'age': u'age6',
#   u'class': u'a hat',
#   u'filename': u'a hat_sketch_age6_cdm_run_v51551650104505.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551650104505',
#   u'shuffler_ind': 7450,
#   u'url': u'https://kiddraw.s3.amazonaws.com/a hat_sketch_age6_cdm_run_v51551650104505.png'},
#  {u'age': u'age5',
#   u'class': u'square',
#   u'filename': u'square_sketch_age5_cdm_run_v51551650436940.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551650436940',
#   u'shuffler_ind': 5947,
#   u'url': u'https://kiddraw.s3.amazonaws.com/square_sketch_age5_cdm_run_v51551650436940.png'},
#  {u'age': u'age5',
#   u'class': u'shape',
#   u'filename': u'shape_sketch_age5_cdm_run_v51551650436940.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551650436940',
#   u'shuffler_ind': 2610,
#   u'url': u'https://kiddraw.s3.amazonaws.com/shape_sketch_age5_cdm_run_v51551650436940.png'},
#  {u'age': u'age5',
#   u'class': u'this square',
#   u'filename': u'this square_sketch_age5_cdm_run_v51551650436940.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551650436940',
#   u'shuffler_ind': 9004,
#   u'url': u'https://kiddraw.s3.amazonaws.com/this square_sketch_age5_cdm_run_v51551650436940.png'},
#  {u'age': u'age5',
#   u'class': u'a hat',
#   u'filename': u'a hat_sketch_age5_cdm_run_v51551650436940.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551650436940',
#   u'shuffler_ind': 13166,
#   u'url': u'https://kiddraw.s3.amazonaws.com/a hat_sketch_age5_cdm_run_v51551650436940.png'},
#  {u'age': u'age3',
#   u'class': u'square',
#   u'filename': u'square_sketch_age3_cdm_run_v51551650539599.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551650539599',
#   u'shuffler_ind': 8697,
#   u'url': u'https://kiddraw.s3.amazonaws.com/square_sketch_age3_cdm_run_v51551650539599.png'},
#  {u'age': u'age3',
#   u'class': u'shape',
#   u'filename': u'shape_sketch_age3_cdm_run_v51551650539599.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551650539599',
#   u'shuffler_ind': 2523,
#   u'url': u'https://kiddraw.s3.amazonaws.com/shape_sketch_age3_cdm_run_v51551650539599.png'},
#  {u'age': u'age3',
#   u'class': u'this square',
#   u'filename': u'this square_sketch_age3_cdm_run_v51551650539599.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551650539599',
#   u'shuffler_ind': 6250,
#   u'url': u'https://kiddraw.s3.amazonaws.com/this square_sketch_age3_cdm_run_v51551650539599.png'},
#  {u'age': u'age3',
#   u'class': u'a lamp',
#   u'filename': u'a lamp_sketch_age3_cdm_run_v51551650539599.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551650539599',
#   u'shuffler_ind': 10293,
#   u'url': u'https://kiddraw.s3.amazonaws.com/a lamp_sketch_age3_cdm_run_v51551650539599.png'},
#  {u'age': u'age3',
#   u'class': u'a cactus',
#   u'filename': u'a cactus_sketch_age3_cdm_run_v51551650539599.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551650539599',
#   u'shuffler_ind': 13533,
#   u'url': u'https://kiddraw.s3.amazonaws.com/a cactus_sketch_age3_cdm_run_v51551650539599.png'},
#  {u'age': u'age3',
#   u'class': u'a camel',
#   u'filename': u'a camel_sketch_age3_cdm_run_v51551650539599.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551650539599',
#   u'shuffler_ind': 5664,
#   u'url': u'https://kiddraw.s3.amazonaws.com/a camel_sketch_age3_cdm_run_v51551650539599.png'},
#  {u'age': u'age3',
#   u'class': u'a tiger',
#   u'filename': u'a tiger_sketch_age3_cdm_run_v51551650539599.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551650539599',
#   u'shuffler_ind': 6911,
#   u'url': u'https://kiddraw.s3.amazonaws.com/a tiger_sketch_age3_cdm_run_v51551650539599.png'},
#  {u'age': u'age3',
#   u'class': u'square',
#   u'filename': u'square_sketch_age3_cdm_run_v51551650770598.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551650770598',
#   u'shuffler_ind': 9332,
#   u'url': u'https://kiddraw.s3.amazonaws.com/square_sketch_age3_cdm_run_v51551650770598.png'},
#  {u'age': u'age3',
#   u'class': u'this square',
#   u'filename': u'this square_sketch_age3_cdm_run_v51551650770598.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551650770598',
#   u'shuffler_ind': 9263,
#   u'url': u'https://kiddraw.s3.amazonaws.com/this square_sketch_age3_cdm_run_v51551650770598.png'},
#  {u'age': u'age3',
#   u'class': u'a lamp',
#   u'filename': u'a lamp_sketch_age3_cdm_run_v51551650770598.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551650770598',
#   u'shuffler_ind': 3463,
#   u'url': u'https://kiddraw.s3.amazonaws.com/a lamp_sketch_age3_cdm_run_v51551650770598.png'},
#  {u'age': u'age3',
#   u'class': u'a hat',
#   u'filename': u'a hat_sketch_age3_cdm_run_v51551650770598.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551650770598',
#   u'shuffler_ind': 11721,
#   u'url': u'https://kiddraw.s3.amazonaws.com/a hat_sketch_age3_cdm_run_v51551650770598.png'},
#  {u'age': u'age3',
#   u'class': u'a whale',
#   u'filename': u'a whale_sketch_age3_cdm_run_v51551650770598.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551650770598',
#   u'shuffler_ind': 3962,
#   u'url': u'https://kiddraw.s3.amazonaws.com/a whale_sketch_age3_cdm_run_v51551650770598.png'},
#  {u'age': u'age3',
#   u'class': u'a tiger',
#   u'filename': u'a tiger_sketch_age3_cdm_run_v51551650770598.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551650770598',
#   u'shuffler_ind': 7294,
#   u'url': u'https://kiddraw.s3.amazonaws.com/a tiger_sketch_age3_cdm_run_v51551650770598.png'},
#  {u'age': u'age3',
#   u'class': u'a bottle',
#   u'filename': u'a bottle_sketch_age3_cdm_run_v51551650770598.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551650770598',
#   u'shuffler_ind': 12528,
#   u'url': u'https://kiddraw.s3.amazonaws.com/a bottle_sketch_age3_cdm_run_v51551650770598.png'},
#  {u'age': u'age3',
#   u'class': u'a cactus',
#   u'filename': u'a cactus_sketch_age3_cdm_run_v51551650770598.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551650770598',
#   u'shuffler_ind': 8212,
#   u'url': u'https://kiddraw.s3.amazonaws.com/a cactus_sketch_age3_cdm_run_v51551650770598.png'},
#  {u'age': u'age3',
#   u'class': u'a watch',
#   u'filename': u'a watch_sketch_age3_cdm_run_v51551650770598.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551650770598',
#   u'shuffler_ind': 6424,
#   u'url': u'https://kiddraw.s3.amazonaws.com/a watch_sketch_age3_cdm_run_v51551650770598.png'},
#  {u'age': u'age3',
#   u'class': u'a camel',
#   u'filename': u'a camel_sketch_age3_cdm_run_v51551650770598.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551650770598',
#   u'shuffler_ind': 5816,
#   u'url': u'https://kiddraw.s3.amazonaws.com/a camel_sketch_age3_cdm_run_v51551650770598.png'},
#  {u'age': u'age2',
#   u'class': u'square',
#   u'filename': u'square_sketch_age2_cdm_run_v51551651144953.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551651144953',
#   u'shuffler_ind': 3455,
#   u'url': u'https://kiddraw.s3.amazonaws.com/square_sketch_age2_cdm_run_v51551651144953.png'},
#  {u'age': u'age2',
#   u'class': u'shape',
#   u'filename': u'shape_sketch_age2_cdm_run_v51551651144953.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551651144953',
#   u'shuffler_ind': 7786,
#   u'url': u'https://kiddraw.s3.amazonaws.com/shape_sketch_age2_cdm_run_v51551651144953.png'},
#  {u'age': u'age2',
#   u'class': u'this square',
#   u'filename': u'this square_sketch_age2_cdm_run_v51551651144953.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551651144953',
#   u'shuffler_ind': 5433,
#   u'url': u'https://kiddraw.s3.amazonaws.com/this square_sketch_age2_cdm_run_v51551651144953.png'},
#  {u'age': u'age2',
#   u'class': u'a tiger',
#   u'filename': u'a tiger_sketch_age2_cdm_run_v51551651144953.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551651144953',
#   u'shuffler_ind': 13275,
#   u'url': u'https://kiddraw.s3.amazonaws.com/a tiger_sketch_age2_cdm_run_v51551651144953.png'},
#  {u'age': u'age2',
#   u'class': u'a watch',
#   u'filename': u'a watch_sketch_age2_cdm_run_v51551651144953.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551651144953',
#   u'shuffler_ind': 2815,
#   u'url': u'https://kiddraw.s3.amazonaws.com/a watch_sketch_age2_cdm_run_v51551651144953.png'},
#  {u'age': u'age2',
#   u'class': u'a cactus',
#   u'filename': u'a cactus_sketch_age2_cdm_run_v51551651144953.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551651144953',
#   u'shuffler_ind': 9620,
#   u'url': u'https://kiddraw.s3.amazonaws.com/a cactus_sketch_age2_cdm_run_v51551651144953.png'},
#  {u'age': u'age2',
#   u'class': u'a lamp',
#   u'filename': u'a lamp_sketch_age2_cdm_run_v51551651144953.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551651144953',
#   u'shuffler_ind': 8677,
#   u'url': u'https://kiddraw.s3.amazonaws.com/a lamp_sketch_age2_cdm_run_v51551651144953.png'},
#  {u'age': u'age2',
#   u'class': u'a bottle',
#   u'filename': u'a bottle_sketch_age2_cdm_run_v51551651144953.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551651144953',
#   u'shuffler_ind': 7076,
#   u'url': u'https://kiddraw.s3.amazonaws.com/a bottle_sketch_age2_cdm_run_v51551651144953.png'},
#  {u'age': u'age2',
#   u'class': u'a hat',
#   u'filename': u'a hat_sketch_age2_cdm_run_v51551651144953.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551651144953',
#   u'shuffler_ind': 2982,
#   u'url': u'https://kiddraw.s3.amazonaws.com/a hat_sketch_age2_cdm_run_v51551651144953.png'},
#  {u'age': u'age2',
#   u'class': u'a camel',
#   u'filename': u'a camel_sketch_age2_cdm_run_v51551651144953.png',
#   u'games': [],
#   u'session_id': u'cdm_run_v51551651144953',
#   u'shuffler_ind': 8377,
#   u'url': u'https://kiddraw.s3.amazonaws.com/a camel_sketch_age2_cdm_run_v51551651144953.png'},
#  ...]

# %%
# set vars 
auth = pd.read_csv('auth.txt', header = None) # this auth.txt file contains the password for the stanford-cogsci.org user
pswd = auth.values[0][0]

# have to fix this to be able to analyze from local
conn = pm.MongoClient('mongodb://stanford:' + pswd + '@127.0.0.1')
db = conn['kiddraw']
coll = db['check_invalid_v5_dev'] # using dev first
# formal check_invalid_v5

# %%
# drop past data
reallyRun = 0
if reallyRun:
    coll.drop()
print 'Currently there are {} records in the development collection'.format(coll.count())
# Out:
# Currently there are 0 records in the development collection

# %%
# upload data to the development collection
reallyRun = 0
if reallyRun:
    for i,_z in enumerate(datajs):
        coll.insert(_z)
        print('Inserted {} records.'.format(i))
        clear_output(wait=True)
else:
    print('Did not insert any new data.')
# Out:
# Inserted 13755 records.

# %%
## check how many records have been retrieved on the mturk study
print 'Currently there are {} records in the collection'.format(coll.count())
#{"games": {"$size": 1}}
# {"_id": ObjectId("5e6a7e7d1943e62410f1ebb3")}
a = coll.find()
numGames = []
for rec in a:
    if len(rec['games']) > 0:
        numGames.append(len(rec['games'])) 
print len(numGames)
# Out:
# Currently there are 13756 records in the collection
# 851
