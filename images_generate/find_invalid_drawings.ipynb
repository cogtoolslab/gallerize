# %%
import os
import csv
import pandas as pd
import numpy as np
from IPython.display import clear_output
import ast
import pymongo as pm

# %%
# take the drawing descriptive file

# %%
# set vars 
auth = pd.read_csv('auth.txt', header = None) # this auth.txt file contains the password for the stanford-cogsci.org user
pswd = auth.values[0][0]
conn = pm.MongoClient('mongodb://stanford:' + pswd + '@127.0.0.1')
db = conn['kiddraw']
coll = db['invalid_draw']

# %%
really_run = 0
if really_run = 1:
    coll.drop()

# %%
from pprint import pprint

cursor = coll.find()
for document in cursor:
      pprint(document)
# Out:
# {u'__v': 0,
#  u'_id': ObjectId('5e77f401365834101ce2ea16'),
#  u'age': u'age3',
#  u'class': u'a camel',
#  u'date': datetime.datetime(2020, 3, 22, 23, 25, 45, 273000),
#  u'filename': u'a camel_sketch_age3_cdm_run_v51555275931780.png',
#  u'session_id': u'cdm_run_v51555275931780',
#  u'worker_id': u'abc'}
# {u'__v': 0,
#  u'_id': ObjectId('5e77f401365834101ce2ea17'),
#  u'age': u'age9',
#  u'class': u'a camel',
#  u'date': datetime.datetime(2020, 3, 22, 23, 25, 47, 396000),
#  u'filename': u'a camel_sketch_age9_cdm_run_v51553885975528.png',
#  u'session_id': u'cdm_run_v51553885975528',
#  u'worker_id': u'abc'}
# {u'__v': 0,
#  u'_id': ObjectId('5e77f460365834101ce2ea18'),
#  u'age': u'age2',
#  u'class': u'a whale',
#  u'date': datetime.datetime(2020, 3, 22, 23, 27, 22, 717000),
#  u'filename': u'a whale_sketch_age2_cdm_run_v51551556208568.png',
#  u'session_id': u'cdm_run_v51551556208568',
#  u'worker_id': u'abc'}
# {u'__v': 0,
#  u'_id': ObjectId('5e77f460365834101ce2ea19'),
#  u'age': u'age3',
#  u'class': u'a whale',
#  u'date': datetime.datetime(2020, 3, 22, 23, 27, 23, 574000),
#  u'filename': u'a whale_sketch_age3_cdm_run_v51553630994448.png',
#  u'session_id': u'cdm_run_v51553630994448',
#  u'worker_id': u'abc'}
# {u'__v': 0,
#  u'_id': ObjectId('5e77f460365834101ce2ea1a'),
#  u'age': u'age3',
#  u'class': u'a whale',
#  u'date': datetime.datetime(2020, 3, 22, 23, 27, 25, 455000),
#  u'filename': u'a whale_sketch_age3_cdm_run_v51555182622937.png',
#  u'session_id': u'cdm_run_v51555182622937',
#  u'worker_id': u'abc'}
# {u'__v': 0,
#  u'_id': ObjectId('5e77f460365834101ce2ea1b'),
#  u'age': u'age6',
#  u'class': u'a whale',
#  u'date': datetime.datetime(2020, 3, 22, 23, 27, 26, 101000),
#  u'filename': u'a whale_sketch_age6_cdm_run_v51557423306618.png',
#  u'session_id': u'cdm_run_v51557423306618',
#  u'worker_id': u'abc'}
# {u'__v': 0,
#  u'_id': ObjectId('5e77f460365834101ce2ea1c'),
#  u'age': u'age2',
#  u'class': u'a whale',
#  u'date': datetime.datetime(2020, 3, 22, 23, 27, 26, 908000),
#  u'filename': u'a whale_sketch_age2_cdm_run_v51558557501843.png',
#  u'session_id': u'cdm_run_v51558557501843',
#  u'worker_id': u'abc'}
# {u'__v': 0,
#  u'_id': ObjectId('5e77f465365834101ce2ea1d'),
#  u'age': u'age10',
#  u'class': u'this square',
#  u'date': datetime.datetime(2020, 3, 22, 23, 27, 29, 764000),
#  u'filename': u'this square_sketch_age10_cdm_run_v51551566413312.png',
#  u'session_id': u'cdm_run_v51551566413312',
#  u'worker_id': u'abc'}
# {u'__v': 0,
#  u'_id': ObjectId('5e77f465365834101ce2ea1e'),
#  u'age': u'age2',
#  u'class': u'this square',
#  u'date': datetime.datetime(2020, 3, 22, 23, 27, 30, 323000),
#  u'filename': u'this square_sketch_age2_cdm_run_v51557858223101.png',
#  u'session_id': u'cdm_run_v51557858223101',
#  u'worker_id': u'abc'}
# {u'__v': 0,
#  u'_id': ObjectId('5e780ba89feb33150f84773b'),
#  u'age': u'age3',
#  u'class': u'a cactus',
#  u'date': datetime.datetime(2020, 3, 23, 1, 6, 43, 350000),
#  u'filename': u'a cactus_sketch_age3_cdm_run_v51553719290359.png',
#  u'session_id': u'cdm_run_v51553719290359',
#  u'worker_id': u'abc'}
# {u'__v': 0,
#  u'_id': ObjectId('5e780ba89feb33150f84773c'),
#  u'age': u'age8',
#  u'class': u'a cactus',
#  u'date': datetime.datetime(2020, 3, 23, 1, 6, 44, 173000),
#  u'filename': u'a cactus_sketch_age8_cdm_run_v51560274881372.png',
#  u'session_id': u'cdm_run_v51560274881372',
#  u'worker_id': u'abc'}
# {u'__v': 0,
#  u'_id': ObjectId('5e780ba89feb33150f84773d'),
#  u'age': u'age5',
#  u'class': u'a cactus',
#  u'date': datetime.datetime(2020, 3, 23, 1, 6, 46, 791000),
#  u'filename': u'a cactus_sketch_age5_cdm_run_v51555439731643.png',
#  u'session_id': u'cdm_run_v51555439731643',
#  u'worker_id': u'abc'}
# {u'__v': 0,
#  u'_id': ObjectId('5e780bb09feb33150f84773e'),
#  u'age': u'age6',
#  u'class': u'a hat',
#  u'date': datetime.datetime(2020, 3, 23, 1, 6, 51, 168000),
#  u'filename': u'a hat_sketch_age6_cdm_run_v51558814651222.png',
#  u'session_id': u'cdm_run_v51558814651222',
#  u'worker_id': u'abc'}
# {u'__v': 0,
#  u'_id': ObjectId('5e780bb09feb33150f84773f'),
#  u'age': u'age5',
#  u'class': u'a hat',
#  u'date': datetime.datetime(2020, 3, 23, 1, 6, 52, 533000),
#  u'filename': u'a hat_sketch_age5_cdm_run_v51558300363058.png',
#  u'session_id': u'cdm_run_v51558300363058',
#  u'worker_id': u'abc'}
# {u'__v': 0,
#  u'_id': ObjectId('5e780bb09feb33150f847740'),
#  u'age': u'age2',
#  u'class': u'a hat',
#  u'date': datetime.datetime(2020, 3, 23, 1, 6, 53, 381000),
#  u'filename': u'a hat_sketch_age2_cdm_run_v51557001534011.png',
#  u'session_id': u'cdm_run_v51557001534011',
#  u'worker_id': u'abc'}
# {u'__v': 0,
#  u'_id': ObjectId('5e780bb09feb33150f847741'),
#  u'age': u'age8',
#  u'class': u'a hat',
#  u'date': datetime.datetime(2020, 3, 23, 1, 6, 54, 91000),
#  u'filename': u'a hat_sketch_age8_cdm_run_v51556818954146.png',
#  u'session_id': u'cdm_run_v51556818954146',
#  u'worker_id': u'abc'}
# {u'__v': 0,
#  u'_id': ObjectId('5e780bb09feb33150f847742'),
#  u'age': u'age3',
#  u'class': u'a hat',
#  u'date': datetime.datetime(2020, 3, 23, 1, 6, 54, 820000),
#  u'filename': u'a hat_sketch_age3_cdm_run_v51552673043456.png',
#  u'session_id': u'cdm_run_v51552673043456',
#  u'worker_id': u'abc'}
# {u'__v': 0,
#  u'_id': ObjectId('5e780bb09feb33150f847743'),
#  u'age': u'age4',
#  u'class': u'a hat',
#  u'date': datetime.datetime(2020, 3, 23, 1, 6, 55, 594000),
#  u'filename': u'a hat_sketch_age4_cdm_run_v51551568336375.png',
#  u'session_id': u'cdm_run_v51551568336375',
#  u'worker_id': u'abc'}
# {u'__v': 0,
#  u'_id': ObjectId('5e780bb59feb33150f847744'),
#  u'age': u'age3',
#  u'class': u'a bottle',
#  u'date': datetime.datetime(2020, 3, 23, 1, 6, 58, 995000),
#  u'filename': u'a bottle_sketch_age3_cdm_run_v51560122325882.png',
#  u'session_id': u'cdm_run_v51560122325882',
#  u'worker_id': u'abc'}
# {u'__v': 0,
#  u'_id': ObjectId('5e780bb59feb33150f847745'),
#  u'age': u'age2',
#  u'class': u'a bottle',
#  u'date': datetime.datetime(2020, 3, 23, 1, 6, 59, 835000),
#  u'filename': u'a bottle_sketch_age2_cdm_run_v51557526172192.png',
#  u'session_id': u'cdm_run_v51557526172192',
#  u'worker_id': u'abc'}
# {u'__v': 0,
#  u'_id': ObjectId('5e780bbd9feb33150f847746'),
#  u'age': u'age6',
#  u'class': u'a lamp',
#  u'date': datetime.datetime(2020, 3, 23, 1, 7, 4, 608000),
#  u'filename': u'a lamp_sketch_age6_cdm_run_v51557082087084.png',
#  u'session_id': u'cdm_run_v51557082087084',
#  u'worker_id': u'abc'}
# {u'__v': 0,
#  u'_id': ObjectId('5e780bbd9feb33150f847747'),
#  u'age': u'age3',
#  u'class': u'a lamp',
#  u'date': datetime.datetime(2020, 3, 23, 1, 7, 5, 722000),
#  u'filename': u'a lamp_sketch_age3_cdm_run_v51555963202270.png',
#  u'session_id': u'cdm_run_v51555963202270',
#  u'worker_id': u'abc'}
# {u'__v': 0,
#  u'_id': ObjectId('5e780bbd9feb33150f847748'),
#  u'age': u'age5',
#  u'class': u'a lamp',
#  u'date': datetime.datetime(2020, 3, 23, 1, 7, 6, 789000),
#  u'filename': u'a lamp_sketch_age5_cdm_run_v51557091648486.png',
#  u'session_id': u'cdm_run_v51557091648486',
#  u'worker_id': u'abc'}
# {u'__v': 0,
#  u'_id': ObjectId('5e780bbd9feb33150f847749'),
#  u'age': u'age8',
#  u'class': u'a lamp',
#  u'date': datetime.datetime(2020, 3, 23, 1, 7, 7, 622000),
#  u'filename': u'a lamp_sketch_age8_cdm_run_v51559501707942.png',
#  u'session_id': u'cdm_run_v51559501707942',
#  u'worker_id': u'abc'}
# {u'__v': 0,
#  u'_id': ObjectId('5e792ef80e4b6e23090ba1b6'),
#  u'age': u'age4',
#  u'class': u'a bottle',
#  u'date': datetime.datetime(2020, 3, 23, 21, 49, 40, 9000),
#  u'filename': u'a bottle_sketch_age4_cdm_run_v51557607263137.png',
#  u'session_id': u'cdm_run_v51557607263137',
#  u'worker_id': u'abc'}
# {u'__v': 0,
#  u'_id': ObjectId('5e792ef80e4b6e23090ba1b7'),
#  u'age': u'age5',
#  u'class': u'a bottle',
#  u'date': datetime.datetime(2020, 3, 23, 21, 49, 41, 834000),
#  u'filename': u'a bottle_sketch_age5_cdm_run_v51558558573619.png',
#  u'session_id': u'cdm_run_v51558558573619',
#  u'worker_id': u'abc'}
# {u'__v': 0,
#  u'_id': ObjectId('5e792ef80e4b6e23090ba1b8'),
#  u'age': u'age4',
#  u'class': u'a bottle',
#  u'date': datetime.datetime(2020, 3, 23, 21, 49, 43, 377000),
#  u'filename': u'a bottle_sketch_age4_cdm_run_v51555609708962.png',
#  u'session_id': u'cdm_run_v51555609708962',
#  u'worker_id': u'abc'}
# {u'__v': 0,
#  u'_id': ObjectId('5e792f210e4b6e23090ba1b9'),
#  u'age': u'age9',
#  u'class': u'a camel',
#  u'date': datetime.datetime(2020, 3, 23, 21, 50, 22, 970000),
#  u'filename': u'a camel_sketch_age9_cdm_run_v51553885975528.png',
#  u'session_id': u'cdm_run_v51553885975528',
#  u'worker_id': u'abc'}
# {u'__v': 0,
#  u'_id': ObjectId('5e792f2b0e4b6e23090ba1ba'),
#  u'age': u'age3',
#  u'class': u'a bottle',
#  u'date': datetime.datetime(2020, 3, 23, 21, 50, 28, 387000),
#  u'filename': u'a bottle_sketch_age3_cdm_run_v51553624274877.png',
#  u'session_id': u'cdm_run_v51553624274877',
#  u'worker_id': u'abc'}
# {u'__v': 0,
#  u'_id': ObjectId('5e792f2b0e4b6e23090ba1bb'),
#  u'age': u'age2',
#  u'class': u'a bottle',
#  u'date': datetime.datetime(2020, 3, 23, 21, 50, 30, 4000),
#  u'filename': u'a bottle_sketch_age2_cdm_run_v51553365717632.png',
#  u'session_id': u'cdm_run_v51553365717632',
#  u'worker_id': u'abc'}
# {u'__v': 0,
#  u'_id': ObjectId('5e792f2b0e4b6e23090ba1bc'),
#  u'age': u'age3',
#  u'class': u'a bottle',
#  u'date': datetime.datetime(2020, 3, 23, 21, 50, 31, 22000),
#  u'filename': u'a bottle_sketch_age3_cdm_run_v51553719290359.png',
#  u'session_id': u'cdm_run_v51553719290359',
#  u'worker_id': u'abc'}
# {u'__v': 0,
#  u'_id': ObjectId('5e792f2b0e4b6e23090ba1bd'),
#  u'age': u'age4',
#  u'class': u'a bottle',
#  u'date': datetime.datetime(2020, 3, 23, 21, 50, 33, 113000),
#  u'filename': u'a bottle_sketch_age4_cdm_run_v51557949727784.png',
#  u'session_id': u'cdm_run_v51557949727784',
#  u'worker_id': u'abc'}
# {u'__v': 0,
#  u'_id': ObjectId('5e7935350e4b6e23090ba1be'),
#  u'age': u'age4',
#  u'class': u'a camel',
#  u'date': datetime.datetime(2020, 3, 23, 22, 16, 14, 207000),
#  u'filename': u'a camel_sketch_age4_cdm_run_v51553457350419.png',
#  u'session_id': u'cdm_run_v51553457350419',
#  u'worker_id': u'abc'}
# {u'__v': 0,
#  u'_id': ObjectId('5e7935350e4b6e23090ba1bf'),
#  u'age': u'age6',
#  u'class': u'a camel',
#  u'date': datetime.datetime(2020, 3, 23, 22, 16, 15, 716000),
#  u'filename': u'a camel_sketch_age6_cdm_run_v51553202122100.png',
#  u'session_id': u'cdm_run_v51553202122100',
#  u'worker_id': u'abc'}
# {u'__v': 0,
#  u'_id': ObjectId('5e7935350e4b6e23090ba1c0'),
#  u'age': u'age3',
#  u'class': u'a camel',
#  u'date': datetime.datetime(2020, 3, 23, 22, 16, 16, 460000),
#  u'filename': u'a camel_sketch_age3_cdm_run_v51553366678343.png',
#  u'session_id': u'cdm_run_v51553366678343',
#  u'worker_id': u'abc'}
# {u'__v': 0,
#  u'_id': ObjectId('5e7935350e4b6e23090ba1c1'),
#  u'age': u'age6',
#  u'class': u'a camel',
#  u'date': datetime.datetime(2020, 3, 23, 22, 16, 18, 461000),
#  u'filename': u'a camel_sketch_age6_cdm_run_v51558819176007.png',
#  u'session_id': u'cdm_run_v51558819176007',
#  u'worker_id': u'abc'}
# {u'__v': 0,
#  u'_id': ObjectId('5e7935350e4b6e23090ba1c2'),
#  u'age': u'age2',
#  u'class': u'a camel',
#  u'date': datetime.datetime(2020, 3, 23, 22, 16, 19, 457000),
#  u'filename': u'a camel_sketch_age2_cdm_run_v51553196050467.png',
#  u'session_id': u'cdm_run_v51553196050467',
#  u'worker_id': u'abc'}
# {u'__v': 0,
#  u'_id': ObjectId('5e7935350e4b6e23090ba1c3'),
#  u'age': u'age3',
#  u'class': u'a camel',
#  u'date': datetime.datetime(2020, 3, 23, 22, 16, 20, 70000),
#  u'filename': u'a camel_sketch_age3_cdm_run_v51559238546713.png',
#  u'session_id': u'cdm_run_v51559238546713',
#  u'worker_id': u'abc'}
# {u'__v': 0,
#  u'_id': ObjectId('5e795714470514277c14b6f6'),
#  u'age': u'age3',
#  u'class': u'a bottle',
#  u'date': datetime.datetime(2020, 3, 24, 0, 40, 47, 879000),
#  u'filename': u'a bottle_sketch_age3_cdm_run_v51559168109481.png',
#  u'session_id': u'cdm_run_v51559168109481',
#  u'worker_id': u'abc'}
# {u'__v': 0,
#  u'_id': ObjectId('5e795714470514277c14b6f7'),
#  u'age': u'age2',
#  u'class': u'a bottle',
#  u'date': datetime.datetime(2020, 3, 24, 0, 40, 48, 879000),
#  u'filename': u'a bottle_sketch_age2_cdm_run_v51554415896767.png',
#  u'session_id': u'cdm_run_v51554415896767',
#  u'worker_id': u'abc'}
# {u'__v': 0,
#  u'_id': ObjectId('5e795714470514277c14b6f8'),
#  u'age': u'age3',
#  u'class': u'a bottle',
#  u'date': datetime.datetime(2020, 3, 24, 0, 40, 50, 172000),
#  u'filename': u'a bottle_sketch_age3_cdm_run_v51551655716898.png',
#  u'session_id': u'cdm_run_v51551655716898',
#  u'worker_id': u'abc'}
# {u'__v': 0,
#  u'_id': ObjectId('5e795714470514277c14b6f9'),
#  u'age': u'age2',
#  u'class': u'a bottle',
#  u'date': datetime.datetime(2020, 3, 24, 0, 40, 51, 455000),
#  u'filename': u'a bottle_sketch_age2_cdm_run_v51557001534011.png',
#  u'session_id': u'cdm_run_v51557001534011',
#  u'worker_id': u'abc'}
# {u'__v': 0,
#  u'_id': ObjectId('5e79571b470514277c14b6fa'),
#  u'age': u'age2',
#  u'class': u'shape',
#  u'date': datetime.datetime(2020, 3, 24, 0, 40, 55, 670000),
#  u'filename': u'shape_sketch_age2_cdm_run_v51558114626994.png',
#  u'session_id': u'cdm_run_v51558114626994',
#  u'worker_id': u'abc'}
# {u'__v': 0,
#  u'_id': ObjectId('5e79571b470514277c14b6fb'),
#  u'age': u'age6',
#  u'class': u'shape',
#  u'date': datetime.datetime(2020, 3, 24, 0, 40, 56, 695000),
#  u'filename': u'shape_sketch_age6_cdm_run_v51558982818703.png',
#  u'session_id': u'cdm_run_v51558982818703',
#  u'worker_id': u'abc'}
# {u'__v': 0,
#  u'_id': ObjectId('5e79571b470514277c14b6fc'),
#  u'age': u'age3',
#  u'class': u'shape',
#  u'date': datetime.datetime(2020, 3, 24, 0, 40, 57, 679000),
#  u'filename': u'shape_sketch_age3_cdm_run_v51558907064732.png',
#  u'session_id': u'cdm_run_v51558907064732',
#  u'worker_id': u'abc'}
# {u'__v': 0,
#  u'_id': ObjectId('5e795721470514277c14b6fd'),
#  u'age': u'age2',
#  u'class': u'a camel',
#  u'date': datetime.datetime(2020, 3, 24, 0, 41, 1, 152000),
#  u'filename': u'a camel_sketch_age2_cdm_run_v51551566293852.png',
#  u'session_id': u'cdm_run_v51551566293852',
#  u'worker_id': u'abc'}
# {u'__v': 0,
#  u'_id': ObjectId('5e795721470514277c14b6fe'),
#  u'age': u'age7',
#  u'class': u'a camel',
#  u'date': datetime.datetime(2020, 3, 24, 0, 41, 2, 411000),
#  u'filename': u'a camel_sketch_age7_cdm_run_v51556821910089.png',
#  u'session_id': u'cdm_run_v51556821910089',
#  u'worker_id': u'abc'}
# {u'__v': 0,
#  u'_id': ObjectId('5e795721470514277c14b6ff'),
#  u'age': u'age4',
#  u'class': u'a camel',
#  u'date': datetime.datetime(2020, 3, 24, 0, 41, 3, 978000),
#  u'filename': u'a camel_sketch_age4_cdm_run_v51554409518093.png',
#  u'session_id': u'cdm_run_v51554409518093',
#  u'worker_id': u'abc'}
# {u'__v': 0,
#  u'_id': ObjectId('5e79572b470514277c14b700'),
#  u'age': u'age2',
#  u'class': u'square',
#  u'date': datetime.datetime(2020, 3, 24, 0, 41, 14, 992000),
#  u'filename': u'square_sketch_age2_cdm_run_v51559153644842.png',
#  u'session_id': u'cdm_run_v51559153644842',
#  u'worker_id': u'abc'}
# {u'__v': 0,
#  u'_id': ObjectId('5e795753470514277c14b701'),
#  u'age': u'age3',
#  u'class': u'a whale',
#  u'date': datetime.datetime(2020, 3, 24, 0, 41, 52, 235000),
#  u'filename': u'a whale_sketch_age3_cdm_run_v51553630994448.png',
#  u'session_id': u'cdm_run_v51553630994448',
#  u'worker_id': u'abc'}
# {u'__v': 0,
#  u'_id': ObjectId('5e795758470514277c14b702'),
#  u'age': u'age4',
#  u'class': u'a tiger',
#  u'date': datetime.datetime(2020, 3, 24, 0, 41, 57, 742000),
#  u'filename': u'a tiger_sketch_age4_cdm_run_v51557256393998.png',
#  u'session_id': u'cdm_run_v51557256393998',
#  u'worker_id': u'abc'}
# {u'__v': 0,
#  u'_id': ObjectId('5e795758470514277c14b703'),
#  u'age': u'age3',
#  u'class': u'a tiger',
#  u'date': datetime.datetime(2020, 3, 24, 0, 41, 58, 945000),
#  u'filename': u'a tiger_sketch_age3_cdm_run_v51552416325491.png',
#  u'session_id': u'cdm_run_v51552416325491',
#  u'worker_id': u'abc'}
# {u'__v': 0,
#  u'_id': ObjectId('5e79575e470514277c14b704'),
#  u'age': u'age10',
#  u'class': u'this square',
#  u'date': datetime.datetime(2020, 3, 24, 0, 42, 2, 71000),
#  u'filename': u'this square_sketch_age10_cdm_run_v51551566413312.png',
#  u'session_id': u'cdm_run_v51551566413312',
#  u'worker_id': u'abc'}
# {u'__v': 0,
#  u'_id': ObjectId('5e795768470514277c14b705'),
#  u'age': u'age2',
#  u'class': u'a cactus',
#  u'date': datetime.datetime(2020, 3, 24, 0, 42, 14, 407000),
#  u'filename': u'a cactus_sketch_age2_cdm_run_v51553713309345.png',
#  u'session_id': u'cdm_run_v51553713309345',
#  u'worker_id': u'abc'}
# {u'__v': 0,
#  u'_id': ObjectId('5e795768470514277c14b706'),
#  u'age': u'age5',
#  u'class': u'a cactus',
#  u'date': datetime.datetime(2020, 3, 24, 0, 42, 15, 103000),
#  u'filename': u'a cactus_sketch_age5_cdm_run_v51553722412744.png',
#  u'session_id': u'cdm_run_v51553722412744',
#  u'worker_id': u'abc'}
# {u'__v': 0,
#  u'_id': ObjectId('5e79576c470514277c14b707'),
#  u'age': u'age4',
#  u'class': u'a lamp',
#  u'date': datetime.datetime(2020, 3, 24, 0, 42, 19, 309000),
#  u'filename': u'a lamp_sketch_age4_cdm_run_v51551382115374.png',
#  u'session_id': u'cdm_run_v51551382115374',
#  u'worker_id': u'abc'}
# {u'__v': 0,
#  u'_id': ObjectId('5e79ac7a470514277c14b708'),
#  u'age': u'age2',
#  u'class': u'a whale',
#  u'date': datetime.datetime(2020, 3, 24, 6, 45, 5, 92000),
#  u'filename': u'a whale_sketch_age2_cdm_run_v51554665411294.png',
#  u'session_id': u'cdm_run_v51554665411294',
#  u'worker_id': u'abc'}
# {u'__v': 0,
#  u'_id': ObjectId('5e79ac7a470514277c14b709'),
#  u'age': u'age6',
#  u'class': u'a whale',
#  u'date': datetime.datetime(2020, 3, 24, 6, 45, 7, 20000),
#  u'filename': u'a whale_sketch_age6_cdm_run_v51560539054002.png',
#  u'session_id': u'cdm_run_v51560539054002',
#  u'worker_id': u'abc'}
# {u'__v': 0,
#  u'_id': ObjectId('5e79ac7a470514277c14b70a'),
#  u'age': u'age4',
#  u'class': u'a whale',
#  u'date': datetime.datetime(2020, 3, 24, 6, 45, 7, 748000),
#  u'filename': u'a whale_sketch_age4_cdm_run_v51552690985575.png',
#  u'session_id': u'cdm_run_v51552690985575',
#  u'worker_id': u'abc'}
# {u'__v': 0,
#  u'_id': ObjectId('5e79ac7a470514277c14b70b'),
#  u'age': u'age4',
#  u'class': u'a whale',
#  u'date': datetime.datetime(2020, 3, 24, 6, 45, 8, 402000),
#  u'filename': u'a whale_sketch_age4_cdm_run_v51560289055430.png',
#  u'session_id': u'cdm_run_v51560289055430',
#  u'worker_id': u'abc'}
# {u'__v': 0,
#  u'_id': ObjectId('5e79ac7a470514277c14b70c'),
#  u'age': u'age2',
#  u'class': u'a whale',
#  u'date': datetime.datetime(2020, 3, 24, 6, 45, 10, 728000),
#  u'filename': u'a whale_sketch_age2_cdm_run_v51553799870318.png',
#  u'session_id': u'cdm_run_v51553799870318',
#  u'worker_id': u'abc'}
# {u'__v': 0,
#  u'_id': ObjectId('5e79ac7a470514277c14b70d'),
#  u'age': u'age6',
#  u'class': u'a whale',
#  u'date': datetime.datetime(2020, 3, 24, 6, 45, 11, 899000),
#  u'filename': u'a whale_sketch_age6_cdm_run_v51555437132132.png',
#  u'session_id': u'cdm_run_v51555437132132',
#  u'worker_id': u'abc'}
# {u'__v': 0,
#  u'_id': ObjectId('5e79ac7a470514277c14b70e'),
#  u'age': u'age7',
#  u'class': u'a whale',
#  u'date': datetime.datetime(2020, 3, 24, 6, 45, 13, 13000),
#  u'filename': u'a whale_sketch_age7_cdm_run_v51558809474892.png',
#  u'session_id': u'cdm_run_v51558809474892',
#  u'worker_id': u'abc'}
# {u'__v': 0,
#  u'_id': ObjectId('5e79ac80470514277c14b70f'),
#  u'age': u'age6',
#  u'class': u'a lamp',
#  u'date': datetime.datetime(2020, 3, 24, 6, 45, 17, 327000),
#  u'filename': u'a lamp_sketch_age6_cdm_run_v51556223436070.png',
#  u'session_id': u'cdm_run_v51556223436070',
#  u'worker_id': u'abc'}
# {u'__v': 0,
#  u'_id': ObjectId('5e79ac80470514277c14b710'),
#  u'age': u'age2',
#  u'class': u'a lamp',
#  u'date': datetime.datetime(2020, 3, 24, 6, 45, 18, 149000),
#  u'filename': u'a lamp_sketch_age2_cdm_run_v51553713309345.png',
#  u'session_id': u'cdm_run_v51553713309345',
#  u'worker_id': u'abc'}
# {u'__v': 0,
#  u'_id': ObjectId('5e79ac80470514277c14b711'),
#  u'age': u'age4',
#  u'class': u'a lamp',
#  u'date': datetime.datetime(2020, 3, 24, 6, 45, 18, 812000),
#  u'filename': u'a lamp_sketch_age4_cdm_run_v51559066630767.png',
#  u'session_id': u'cdm_run_v51559066630767',
#  u'worker_id': u'abc'}
# {u'__v': 0,
#  u'_id': ObjectId('5e79ac85470514277c14b712'),
#  u'age': u'age3',
#  u'class': u'this square',
#  u'date': datetime.datetime(2020, 3, 24, 6, 45, 21, 486000),
#  u'filename': u'this square_sketch_age3_cdm_run_v51553632017453.png',
#  u'session_id': u'cdm_run_v51553632017453',
#  u'worker_id': u'abc'}
# {u'__v': 0,
#  u'_id': ObjectId('5e79ac85470514277c14b713'),
#  u'age': u'age2',
#  u'class': u'this square',
#  u'date': datetime.datetime(2020, 3, 24, 6, 45, 23, 134000),
#  u'filename': u'this square_sketch_age2_cdm_run_v51551551562660.png',
#  u'session_id': u'cdm_run_v51551551562660',
#  u'worker_id': u'abc'}
# {u'__v': 0,
#  u'_id': ObjectId('5e79ac85470514277c14b714'),
#  u'age': u'age5',
#  u'class': u'this square',
#  u'date': datetime.datetime(2020, 3, 24, 6, 45, 24, 118000),
#  u'filename': u'this square_sketch_age5_cdm_run_v51560201763325.png',
#  u'session_id': u'cdm_run_v51560201763325',
#  u'worker_id': u'abc'}
# {u'__v': 0,
#  u'_id': ObjectId('5e79ad29470514277c14b715'),
#  u'age': u'age9',
#  u'class': u'a hat',
#  u'date': datetime.datetime(2020, 3, 24, 6, 47, 54, 541000),
#  u'filename': u'a hat_sketch_age9_cdm_run_v51554581781825.png',
#  u'session_id': u'cdm_run_v51554581781825',
#  u'worker_id': u'abc'}
# {u'__v': 0,
#  u'_id': ObjectId('5e79ad29470514277c14b716'),
#  u'age': u'age4',
#  u'class': u'a hat',
#  u'date': datetime.datetime(2020, 3, 24, 6, 47, 55, 278000),
#  u'filename': u'a hat_sketch_age4_cdm_run_v51558561332470.png',
#  u'session_id': u'cdm_run_v51558561332470',
#  u'worker_id': u'abc'}
# {u'__v': 0,
#  u'_id': ObjectId('5e79ad29470514277c14b717'),
#  u'age': u'age2',
#  u'class': u'a hat',
#  u'date': datetime.datetime(2020, 3, 24, 6, 47, 56, 280000),
#  u'filename': u'a hat_sketch_age2_cdm_run_v51560275497493.png',
#  u'session_id': u'cdm_run_v51560275497493',
#  u'worker_id': u'abc'}
# {u'__v': 0,
#  u'_id': ObjectId('5e79ad29470514277c14b718'),
#  u'age': u'age2',
#  u'class': u'a hat',
#  u'date': datetime.datetime(2020, 3, 24, 6, 47, 57, 39000),
#  u'filename': u'a hat_sketch_age2_cdm_run_v51551555633216.png',
#  u'session_id': u'cdm_run_v51551555633216',
#  u'worker_id': u'abc'}
# {u'__v': 0,
#  u'_id': ObjectId('5e79ad29470514277c14b719'),
#  u'age': u'age2',
#  u'class': u'a hat',
#  u'date': datetime.datetime(2020, 3, 24, 6, 47, 58, 808000),
#  u'filename': u'a hat_sketch_age2_cdm_run_v51553714131224.png',
#  u'session_id': u'cdm_run_v51553714131224',
#  u'worker_id': u'abc'}
# {u'__v': 0,
#  u'_id': ObjectId('5e79ad29470514277c14b71a'),
#  u'age': u'age3',
#  u'class': u'a hat',
#  u'date': datetime.datetime(2020, 3, 24, 6, 47, 59, 849000),
#  u'filename': u'a hat_sketch_age3_cdm_run_v51552250404594.png',
#  u'session_id': u'cdm_run_v51552250404594',
#  u'worker_id': u'abc'}
# {u'__v': 0,
#  u'_id': ObjectId('5e79ad29470514277c14b71b'),
#  u'age': u'age4',
#  u'class': u'a hat',
#  u'date': datetime.datetime(2020, 3, 24, 6, 48, 3, 7000),
#  u'filename': u'a hat_sketch_age4_cdm_run_v51554673781770.png',
#  u'session_id': u'cdm_run_v51554673781770',
#  u'worker_id': u'abc'}
# {u'__v': 0,
#  u'_id': ObjectId('5e79ad29470514277c14b71c'),
#  u'age': u'age4',
#  u'class': u'a hat',
#  u'date': datetime.datetime(2020, 3, 24, 6, 48, 5, 3000),
#  u'filename': u'a hat_sketch_age4_cdm_run_v51559083327293.png',
#  u'session_id': u'cdm_run_v51559083327293',
#  u'worker_id': u'abc'}
# {u'__v': 0,
#  u'_id': ObjectId('5e79ad29470514277c14b71d'),
#  u'age': u'age2',
#  u'class': u'a hat',
#  u'date': datetime.datetime(2020, 3, 24, 6, 48, 6, 908000),
#  u'filename': u'a hat_sketch_age2_cdm_run_v51555181067535.png',
#  u'session_id': u'cdm_run_v51555181067535',
#  u'worker_id': u'abc'}
# {u'__v': 0,
#  u'_id': ObjectId('5e79ad2e470514277c14b71e'),
#  u'age': u'age2',
#  u'class': u'square',
#  u'date': datetime.datetime(2020, 3, 24, 6, 48, 11, 812000),
#  u'filename': u'square_sketch_age2_cdm_run_v51558984416136.png',
#  u'session_id': u'cdm_run_v51558984416136',
#  u'worker_id': u'abc'}
# {u'__v': 0,
#  u'_id': ObjectId('5e79ad2e470514277c14b71f'),
#  u'age': u'age2',
#  u'class': u'square',
#  u'date': datetime.datetime(2020, 3, 24, 6, 48, 13, 184000),
#  u'filename': u'square_sketch_age2_cdm_run_v51555438437839.png',
#  u'session_id': u'cdm_run_v51555438437839',
#  u'worker_id': u'abc'}
# {u'__v': 0,
#  u'_id': ObjectId('5e79ad37470514277c14b720'),
#  u'age': u'age4',
#  u'class': u'a camel',
#  u'date': datetime.datetime(2020, 3, 24, 6, 48, 17, 37000),
#  u'filename': u'a camel_sketch_age4_cdm_run_v51551560616195.png',
#  u'session_id': u'cdm_run_v51551560616195',
#  u'worker_id': u'abc'}
# {u'__v': 0,
#  u'_id': ObjectId('5e79ad37470514277c14b721'),
#  u'age': u'age4',
#  u'class': u'a camel',
#  u'date': datetime.datetime(2020, 3, 24, 6, 48, 17, 795000),
#  u'filename': u'a camel_sketch_age4_cdm_run_v51558478241692.png',
#  u'session_id': u'cdm_run_v51558478241692',
#  u'worker_id': u'abc'}
# {u'__v': 0,
#  u'_id': ObjectId('5e79ad37470514277c14b722'),
#  u'age': u'age3',
#  u'class': u'a camel',
#  u'date': datetime.datetime(2020, 3, 24, 6, 48, 18, 620000),
#  u'filename': u'a camel_sketch_age3_cdm_run_v51551467671452.png',
#  u'session_id': u'cdm_run_v51551467671452',
#  u'worker_id': u'abc'}
# {u'__v': 0,
#  u'_id': ObjectId('5e79ad37470514277c14b723'),
#  u'age': u'age3',
#  u'class': u'a camel',
#  u'date': datetime.datetime(2020, 3, 24, 6, 48, 20, 179000),
#  u'filename': u'a camel_sketch_age3_cdm_run_v51553798799196.png',
#  u'session_id': u'cdm_run_v51553798799196',
#  u'worker_id': u'abc'}
# {u'__v': 0,
#  u'_id': ObjectId('5e79ad37470514277c14b724'),
#  u'age': u'age6',
#  u'class': u'a camel',
#  u'date': datetime.datetime(2020, 3, 24, 6, 48, 21, 173000),
#  u'filename': u'a camel_sketch_age6_cdm_run_v51555697712904.png',
#  u'session_id': u'cdm_run_v51555697712904',
#  u'worker_id': u'abc'}
# {u'__v': 0,
#  u'_id': ObjectId('5e79ad54470514277c14b725'),
#  u'age': u'age4',
#  u'class': u'a cactus',
#  u'date': datetime.datetime(2020, 3, 24, 6, 48, 49, 6000),
#  u'filename': u'a cactus_sketch_age4_cdm_run_v51554323455895.png',
#  u'session_id': u'cdm_run_v51554323455895',
#  u'worker_id': u'abc'}
# {u'__v': 0,
#  u'_id': ObjectId('5e79ad54470514277c14b726'),
#  u'age': u'age10',
#  u'class': u'a cactus',
#  u'date': datetime.datetime(2020, 3, 24, 6, 48, 49, 580000),
#  u'filename': u'a cactus_sketch_age10_cdm_run_v51556399272012.png',
#  u'session_id': u'cdm_run_v51556399272012',
#  u'worker_id': u'abc'}
# {u'__v': 0,
#  u'_id': ObjectId('5e79ad54470514277c14b727'),
#  u'age': u'age3',
#  u'class': u'a cactus',
#  u'date': datetime.datetime(2020, 3, 24, 6, 48, 50, 848000),
#  u'filename': u'a cactus_sketch_age3_cdm_run_v51558990041763.png',
#  u'session_id': u'cdm_run_v51558990041763',
#  u'worker_id': u'abc'}
# {u'__v': 0,
#  u'_id': ObjectId('5e79ad5b470514277c14b728'),
#  u'age': u'age5',
#  u'class': u'a bottle',
#  u'date': datetime.datetime(2020, 3, 24, 6, 48, 54, 225000),
#  u'filename': u'a bottle_sketch_age5_cdm_run_v51551572317881.png',
#  u'session_id': u'cdm_run_v51551572317881',
#  u'worker_id': u'abc'}
# {u'__v': 0,
#  u'_id': ObjectId('5e79ad5b470514277c14b729'),
#  u'age': u'age2',
#  u'class': u'a bottle',
#  u'date': datetime.datetime(2020, 3, 24, 6, 48, 56, 2000),
#  u'filename': u'a bottle_sketch_age2_cdm_run_v51558296395206.png',
#  u'session_id': u'cdm_run_v51558296395206',
#  u'worker_id': u'abc'}
# {u'__v': 0,
#  u'_id': ObjectId('5e79ad5b470514277c14b72a'),
#  u'age': u'age4',
#  u'class': u'a bottle',
#  u'date': datetime.datetime(2020, 3, 24, 6, 48, 56, 834000),
#  u'filename': u'a bottle_sketch_age4_cdm_run_v51554672816400.png',
#  u'session_id': u'cdm_run_v51554672816400',
#  u'worker_id': u'abc'}
# {u'__v': 0,
#  u'_id': ObjectId('5e79ad5b470514277c14b72b'),
#  u'age': u'age3',
#  u'class': u'a bottle',
#  u'date': datetime.datetime(2020, 3, 24, 6, 48, 58, 336000),
#  u'filename': u'a bottle_sketch_age3_cdm_run_v51553291562738.png',
#  u'session_id': u'cdm_run_v51553291562738',
#  u'worker_id': u'abc'}
# {u'__v': 0,
#  u'_id': ObjectId('5e79ad5e470514277c14b72c'),
#  u'age': u'age7',
#  u'class': u'a tiger',
#  u'date': datetime.datetime(2020, 3, 24, 6, 49, 1, 624000),
#  u'filename': u'a tiger_sketch_age7_cdm_run_v51555530646416.png',
#  u'session_id': u'cdm_run_v51555530646416',
#  u'worker_id': u'abc'}
# {u'__v': 0,
#  u'_id': ObjectId('5e79b112470514277c14b72d'),
#  u'age': u'age4',
#  u'class': u'a hat',
#  u'date': datetime.datetime(2020, 3, 24, 7, 4, 48, 471000),
#  u'filename': u'a hat_sketch_age4_cdm_run_v51559066945318.png',
#  u'session_id': u'cdm_run_v51559066945318',
#  u'worker_id': u'abc'}
# {u'__v': 0,
#  u'_id': ObjectId('5e79b112470514277c14b72e'),
#  u'age': u'age9',
#  u'class': u'a hat',
#  u'date': datetime.datetime(2020, 3, 24, 7, 4, 49, 191000),
#  u'filename': u'a hat_sketch_age9_cdm_run_v51551912419638.png',
#  u'session_id': u'cdm_run_v51551912419638',
#  u'worker_id': u'abc'}
# {u'__v': 0,
#  u'_id': ObjectId('5e79b117470514277c14b72f'),
#  u'age': u'age3',
#  u'class': u'this square',
#  u'date': datetime.datetime(2020, 3, 24, 7, 4, 52, 875000),
#  u'filename': u'this square_sketch_age3_cdm_run_v51559587567464.png',
#  u'session_id': u'cdm_run_v51559587567464',
#  u'worker_id': u'abc'}
# {u'__v': 0,
#  u'_id': ObjectId('5e79b117470514277c14b730'),
#  u'age': u'age4',
#  u'class': u'this square',
#  u'date': datetime.datetime(2020, 3, 24, 7, 4, 53, 795000),
#  u'filename': u'this square_sketch_age4_cdm_run_v51551818426346.png',
#  u'session_id': u'cdm_run_v51551818426346',
#  u'worker_id': u'abc'}
# {u'__v': 0,
#  u'_id': ObjectId('5e79b117470514277c14b731'),
#  u'age': u'age3',
#  u'class': u'this square',
#  u'date': datetime.datetime(2020, 3, 24, 7, 4, 54, 578000),
#  u'filename': u'this square_sketch_age3_cdm_run_v51551816550329.png',
#  u'session_id': u'cdm_run_v51551816550329',
#  u'worker_id': u'abc'}
# {u'__v': 0,
#  u'_id': ObjectId('5e79b11f470514277c14b732'),
#  u'age': u'age4',
#  u'class': u'a camel',
#  u'date': datetime.datetime(2020, 3, 24, 7, 4, 58, 488000),
#  u'filename': u'a camel_sketch_age4_cdm_run_v51551557961833.png',
#  u'session_id': u'cdm_run_v51551557961833',
#  u'worker_id': u'abc'}
# {u'__v': 0,
#  u'_id': ObjectId('5e79b11f470514277c14b733'),
#  u'age': u'age3',
#  u'class': u'a camel',
#  u'date': datetime.datetime(2020, 3, 24, 7, 4, 59, 618000),
#  u'filename': u'a camel_sketch_age3_cdm_run_v51559168109481.png',
#  u'session_id': u'cdm_run_v51559168109481',
#  u'worker_id': u'abc'}
# {u'__v': 0,
#  u'_id': ObjectId('5e79b11f470514277c14b734'),
#  u'age': u'age3',
#  u'class': u'a camel',
#  u'date': datetime.datetime(2020, 3, 24, 7, 5, 0, 508000),
#  u'filename': u'a camel_sketch_age3_cdm_run_v51556221417453.png',
#  u'session_id': u'cdm_run_v51556221417453',
#  u'worker_id': u'abc'}
# {u'__v': 0,
#  u'_id': ObjectId('5e79b11f470514277c14b735'),
#  u'age': u'age2',
#  u'class': u'a camel',
#  u'date': datetime.datetime(2020, 3, 24, 7, 5, 1, 389000),
#  u'filename': u'a camel_sketch_age2_cdm_run_v51551476361991.png',
#  u'session_id': u'cdm_run_v51551476361991',
#  u'worker_id': u'abc'}
# {u'__v': 0,
#  u'_id': ObjectId('5e79b11f470514277c14b736'),
#  u'age': u'age5',
#  u'class': u'a camel',
#  u'date': datetime.datetime(2020, 3, 24, 7, 5, 2, 415000),
#  u'filename': u'a camel_sketch_age5_cdm_run_v51557352699301.png',
#  u'session_id': u'cdm_run_v51557352699301',
#  u'worker_id': u'abc'}
# {u'__v': 0,
#  u'_id': ObjectId('5e79b1a6470514277c14b737'),
#  u'age': u'age4',
#  u'class': u'a cactus',
#  u'date': datetime.datetime(2020, 3, 24, 7, 7, 7, 60000),
#  u'filename': u'a cactus_sketch_age4_cdm_run_v51559083327293.png',
#  u'session_id': u'cdm_run_v51559083327293',
#  u'worker_id': u'abc'}
# {u'__v': 0,
#  u'_id': ObjectId('5e79b1a6470514277c14b738'),
#  u'age': u'age10',
#  u'class': u'a cactus',
#  u'date': datetime.datetime(2020, 3, 24, 7, 7, 8, 254000),
#  u'filename': u'a cactus_sketch_age10_cdm_run_v51556390693353.png',
#  u'session_id': u'cdm_run_v51556390693353',
#  u'worker_id': u'abc'}
# {u'__v': 0,
#  u'_id': ObjectId('5e79b1a6470514277c14b739'),
#  u'age': u'age3',
#  u'class': u'a cactus',
#  u'date': datetime.datetime(2020, 3, 24, 7, 7, 10, 507000),
#  u'filename': u'a cactus_sketch_age3_cdm_run_v51559933816262.png',
#  u'session_id': u'cdm_run_v51559933816262',
#  u'worker_id': u'abc'}
# {u'__v': 0,
#  u'_id': ObjectId('5e79b1a6470514277c14b73a'),
#  u'age': u'age5',
#  u'class': u'a cactus',
#  u'date': datetime.datetime(2020, 3, 24, 7, 7, 11, 203000),
#  u'filename': u'a cactus_sketch_age5_cdm_run_v51558977579947.png',
#  u'session_id': u'cdm_run_v51558977579947',
#  u'worker_id': u'abc'}
# {u'__v': 0,
#  u'_id': ObjectId('5e79b1a6470514277c14b73b'),
#  u'age': u'age2',
#  u'class': u'a cactus',
#  u'date': datetime.datetime(2020, 3, 24, 7, 7, 11, 954000),
#  u'filename': u'a cactus_sketch_age2_cdm_run_v51559415633640.png',
#  u'session_id': u'cdm_run_v51559415633640',
#  u'worker_id': u'abc'}
# {u'__v': 0,
#  u'_id': ObjectId('5e79b1a6470514277c14b73c'),
#  u'age': u'age7',
#  u'class': u'a cactus',
#  u'date': datetime.datetime(2020, 3, 24, 7, 7, 12, 704000),
#  u'filename': u'a cactus_sketch_age7_cdm_run_v51555009788317.png',
#  u'session_id': u'cdm_run_v51555009788317',
#  u'worker_id': u'abc'}
# {u'__v': 0,
#  u'_id': ObjectId('5e79b1a6470514277c14b73d'),
#  u'age': u'age5',
#  u'class': u'a cactus',
#  u'date': datetime.datetime(2020, 3, 24, 7, 7, 13, 254000),
#  u'filename': u'a cactus_sketch_age5_cdm_run_v51552260590539.png',
#  u'session_id': u'cdm_run_v51552260590539',
#  u'worker_id': u'abc'}
# {u'__v': 0,
#  u'_id': ObjectId('5e79b1a6470514277c14b73e'),
#  u'age': u'age2',
#  u'class': u'a cactus',
#  u'date': datetime.datetime(2020, 3, 24, 7, 7, 14, 578000),
#  u'filename': u'a cactus_sketch_age2_cdm_run_v51553120825260.png',
#  u'session_id': u'cdm_run_v51553120825260',
#  u'worker_id': u'abc'}
# {u'__v': 0,
#  u'_id': ObjectId('5e79b1a6470514277c14b73f'),
#  u'age': u'age8',
#  u'class': u'a cactus',
#  u'date': datetime.datetime(2020, 3, 24, 7, 7, 16, 557000),
#  u'filename': u'a cactus_sketch_age8_cdm_run_v51559330860169.png',
#  u'session_id': u'cdm_run_v51559330860169',
#  u'worker_id': u'abc'}
# {u'__v': 0,
#  u'_id': ObjectId('5e79b1a6470514277c14b740'),
#  u'age': u'age5',
#  u'class': u'a cactus',
#  u'date': datetime.datetime(2020, 3, 24, 7, 7, 17, 365000),
#  u'filename': u'a cactus_sketch_age5_cdm_run_v51559683260140.png',
#  u'session_id': u'cdm_run_v51559683260140',
#  u'worker_id': u'abc'}
# {u'__v': 0,
#  u'_id': ObjectId('5e79b1a6470514277c14b741'),
#  u'age': u'age6',
#  u'class': u'a cactus',
#  u'date': datetime.datetime(2020, 3, 24, 7, 7, 18, 43000),
#  u'filename': u'a cactus_sketch_age6_cdm_run_v51559244475149.png',
#  u'session_id': u'cdm_run_v51559244475149',
#  u'worker_id': u'abc'}
# {u'__v': 0,
#  u'_id': ObjectId('5e79b1e0470514277c14b742'),
#  u'age': u'age2',
#  u'class': u'a lamp',
#  u'date': datetime.datetime(2020, 3, 24, 7, 8, 11, 755000),
#  u'filename': u'a lamp_sketch_age2_cdm_run_v51558820579115.png',
#  u'session_id': u'cdm_run_v51558820579115',
#  u'worker_id': u'abc'}
# {u'__v': 0,
#  u'_id': ObjectId('5e79b1e0470514277c14b743'),
#  u'age': u'age2',
#  u'class': u'a lamp',
#  u'date': datetime.datetime(2020, 3, 24, 7, 8, 13, 38000),
#  u'filename': u'a lamp_sketch_age2_cdm_run_v51551552712312.png',
#  u'session_id': u'cdm_run_v51551552712312',
#  u'worker_id': u'abc'}
# {u'__v': 0,
#  u'_id': ObjectId('5e79b1e0470514277c14b744'),
#  u'age': u'age2',
#  u'class': u'a lamp',
#  u'date': datetime.datetime(2020, 3, 24, 7, 8, 13, 983000),
#  u'filename': u'a lamp_sketch_age2_cdm_run_v51556826901801.png',
#  u'session_id': u'cdm_run_v51556826901801',
#  u'worker_id': u'abc'}
# {u'__v': 0,
#  u'_id': ObjectId('5e79b53f470514277c14b745'),
#  u'age': u'age7',
#  u'class': u'a bottle',
#  u'date': datetime.datetime(2020, 3, 24, 7, 22, 35, 791000),
#  u'filename': u'a bottle_sketch_age7_cdm_run_v51556821910089.png',
#  u'session_id': u'cdm_run_v51556821910089',
#  u'worker_id': u'abc'}
# {u'__v': 0,
#  u'_id': ObjectId('5e79b53f470514277c14b746'),
#  u'age': u'age2',
#  u'class': u'a bottle',
#  u'date': datetime.datetime(2020, 3, 24, 7, 22, 37, 931000),
#  u'filename': u'a bottle_sketch_age2_cdm_run_v51551552712312.png',
#  u'session_id': u'cdm_run_v51551552712312',
#  u'worker_id': u'abc'}
# {u'__v': 0,
#  u'_id': ObjectId('5e79b53f470514277c14b747'),
#  u'age': u'age6',
#  u'class': u'a bottle',
#  u'date': datetime.datetime(2020, 3, 24, 7, 22, 38, 714000),
#  u'filename': u'a bottle_sketch_age6_cdm_run_v51558562954276.png',
#  u'session_id': u'cdm_run_v51558562954276',
#  u'worker_id': u'abc'}
# {u'__v': 0,
#  u'_id': ObjectId('5e7a4d6f84f69a325ccf3889'),
#  u'age': u'age8',
#  u'class': u'a whale',
#  u'date': datetime.datetime(2020, 3, 24, 18, 11, 42, 747000),
#  u'filename': u'a whale_sketch_age8_cdm_run_v51556301427958.png',
#  u'session_id': u'cdm_run_v51556301427958',
#  u'worker_id': u'abc'}
# {u'__v': 0,
#  u'_id': ObjectId('5e7a4d6f84f69a325ccf388a'),
#  u'age': u'age2',
#  u'class': u'a whale',
#  u'date': datetime.datetime(2020, 3, 24, 18, 11, 43, 618000),
#  u'filename': u'a whale_sketch_age2_cdm_run_v51551552712312.png',
#  u'session_id': u'cdm_run_v51551552712312',
#  u'worker_id': u'abc'}
# {u'__v': 0,
#  u'_id': ObjectId('5e7a4d6f84f69a325ccf388b'),
#  u'age': u'age2',
#  u'class': u'a whale',
#  u'date': datetime.datetime(2020, 3, 24, 18, 11, 44, 814000),
#  u'filename': u'a whale_sketch_age2_cdm_run_v51560457777126.png',
#  u'session_id': u'cdm_run_v51560457777126',
#  u'worker_id': u'abc'}
# {u'__v': 0,
#  u'_id': ObjectId('5e7a4d6f84f69a325ccf388c'),
#  u'age': u'age2',
#  u'class': u'a whale',
#  u'date': datetime.datetime(2020, 3, 24, 18, 11, 45, 661000),
#  u'filename': u'a whale_sketch_age2_cdm_run_v51554839103644.png',
#  u'session_id': u'cdm_run_v51554839103644',
#  u'worker_id': u'abc'}
# {u'__v': 0,
#  u'_id': ObjectId('5e7a4d6f84f69a325ccf388d'),
#  u'age': u'age8',
#  u'class': u'a whale',
#  u'date': datetime.datetime(2020, 3, 24, 18, 11, 46, 575000),
#  u'filename': u'a whale_sketch_age8_cdm_run_v51554317223964.png',
#  u'session_id': u'cdm_run_v51554317223964',
#  u'worker_id': u'abc'}
# {u'__v': 0,
#  u'_id': ObjectId('5e7a4d6f84f69a325ccf388e'),
#  u'age': u'age10',
#  u'class': u'a whale',
#  u'date': datetime.datetime(2020, 3, 24, 18, 11, 56, 759000),
#  u'filename': u'a whale_sketch_age10_cdm_run_v51556224191743.png',
#  u'session_id': u'cdm_run_v51556224191743',
#  u'worker_id': u'abc'}
# {u'__v': 0,
#  u'_id': ObjectId('5e7a4d6f84f69a325ccf388f'),
#  u'age': u'age3',
#  u'class': u'a whale',
#  u'date': datetime.datetime(2020, 3, 24, 18, 11, 57, 752000),
#  u'filename': u'a whale_sketch_age3_cdm_run_v51559168109481.png',
#  u'session_id': u'cdm_run_v51559168109481',
#  u'worker_id': u'abc'}
# {u'__v': 0,
#  u'_id': ObjectId('5e7a4d7f84f69a325ccf3890'),
#  u'age': u'age2',
#  u'class': u'a bottle',
#  u'date': datetime.datetime(2020, 3, 24, 18, 12, 2, 581000),
#  u'filename': u'a bottle_sketch_age2_cdm_run_v51557352080502.png',
#  u'session_id': u'cdm_run_v51557352080502',
#  u'worker_id': u'abc'}
# {u'__v': 0,
#  u'_id': ObjectId('5e7a4d7f84f69a325ccf3891'),
#  u'age': u'age3',
#  u'class': u'a bottle',
#  u'date': datetime.datetime(2020, 3, 24, 18, 12, 3, 380000),
#  u'filename': u'a bottle_sketch_age3_cdm_run_v51553973426563.png',
#  u'session_id': u'cdm_run_v51553973426563',
#  u'worker_id': u'abc'}
# {u'__v': 0,
#  u'_id': ObjectId('5e7a4d7f84f69a325ccf3892'),
#  u'age': u'age10',
#  u'class': u'a bottle',
#  u'date': datetime.datetime(2020, 3, 24, 18, 12, 6, 544000),
#  u'filename': u'a bottle_sketch_age10_cdm_run_v51558997412939.png',
#  u'session_id': u'cdm_run_v51558997412939',
#  u'worker_id': u'abc'}
# {u'__v': 0,
#  u'_id': ObjectId('5e7a4d7f84f69a325ccf3893'),
#  u'age': u'age7',
#  u'class': u'a bottle',
#  u'date': datetime.datetime(2020, 3, 24, 18, 12, 7, 232000),
#  u'filename': u'a bottle_sketch_age7_cdm_run_v51555091330174.png',
#  u'session_id': u'cdm_run_v51555091330174',
#  u'worker_id': u'abc'}
# {u'__v': 0,
#  u'_id': ObjectId('5e7a4d7f84f69a325ccf3894'),
#  u'age': u'age3',
#  u'class': u'a bottle',
#  u'date': datetime.datetime(2020, 3, 24, 18, 12, 8, 96000),
#  u'filename': u'a bottle_sketch_age3_cdm_run_v51559933816262.png',
#  u'session_id': u'cdm_run_v51559933816262',
#  u'worker_id': u'abc'}
# {u'__v': 0,
#  u'_id': ObjectId('5e7a4d7f84f69a325ccf3895'),
#  u'age': u'age2',
#  u'class': u'a bottle',
#  u'date': datetime.datetime(2020, 3, 24, 18, 12, 9, 25000),
#  u'filename': u'a bottle_sketch_age2_cdm_run_v51551641090157.png',
#  u'session_id': u'cdm_run_v51551641090157',
#  u'worker_id': u'abc'}
# {u'__v': 0,
#  u'_id': ObjectId('5e7a4d7f84f69a325ccf3896'),
#  u'age': u'age4',
#  u'class': u'a bottle',
#  u'date': datetime.datetime(2020, 3, 24, 18, 12, 9, 793000),
#  u'filename': u'a bottle_sketch_age4_cdm_run_v51555284029058.png',
#  u'session_id': u'cdm_run_v51555284029058',
#  u'worker_id': u'abc'}
# {u'__v': 0,
#  u'_id': ObjectId('5e7a4d7f84f69a325ccf3897'),
#  u'age': u'age4',
#  u'class': u'a bottle',
#  u'date': datetime.datetime(2020, 3, 24, 18, 12, 10, 479000),
#  u'filename': u'a bottle_sketch_age4_cdm_run_v51553117783837.png',
#  u'session_id': u'cdm_run_v51553117783837',
#  u'worker_id': u'abc'}
# {u'__v': 0,
#  u'_id': ObjectId('5e7a4d7f84f69a325ccf3898'),
#  u'age': u'age3',
#  u'class': u'a bottle',
#  u'date': datetime.datetime(2020, 3, 24, 18, 12, 11, 175000),
#  u'filename': u'a bottle_sketch_age3_cdm_run_v51551816550329.png',
#  u'session_id': u'cdm_run_v51551816550329',
#  u'worker_id': u'abc'}
# {u'__v': 0,
#  u'_id': ObjectId('5e7a4d7f84f69a325ccf3899'),
#  u'age': u'age4',
#  u'class': u'a bottle',
#  u'date': datetime.datetime(2020, 3, 24, 18, 12, 12, 305000),
#  u'filename': u'a bottle_sketch_age4_cdm_run_v51554837617296.png',
#  u'session_id': u'cdm_run_v51554837617296',
#  u'worker_id': u'abc'}
# {u'__v': 0,
#  u'_id': ObjectId('5e7a4d7f84f69a325ccf389a'),
#  u'age': u'age5',
#  u'class': u'a bottle',
#  u'date': datetime.datetime(2020, 3, 24, 18, 12, 13, 129000),
#  u'filename': u'a bottle_sketch_age5_cdm_run_v51554842759142.png',
#  u'session_id': u'cdm_run_v51554842759142',
#  u'worker_id': u'abc'}
# {u'__v': 0,
#  u'_id': ObjectId('5e7a4d7f84f69a325ccf389b'),
#  u'age': u'age5',
#  u'class': u'a bottle',
#  u'date': datetime.datetime(2020, 3, 24, 18, 12, 13, 711000),
#  u'filename': u'a bottle_sketch_age5_cdm_run_v51558476298638.png',
#  u'session_id': u'cdm_run_v51558476298638',
#  u'worker_id': u'abc'}
# {u'__v': 0,
#  u'_id': ObjectId('5e7a4d7f84f69a325ccf389c'),
#  u'age': u'age10',
#  u'class': u'a bottle',
#  u'date': datetime.datetime(2020, 3, 24, 18, 12, 14, 646000),
#  u'filename': u'a bottle_sketch_age10_cdm_run_v51555281833130.png',
#  u'session_id': u'cdm_run_v51555281833130',
#  u'worker_id': u'abc'}
# {u'__v': 0,
#  u'_id': ObjectId('5e7a4d8984f69a325ccf389d'),
#  u'age': u'age4',
#  u'class': u'a hat',
#  u'date': datetime.datetime(2020, 3, 24, 18, 12, 17, 917000),
#  u'filename': u'a hat_sketch_age4_cdm_run_v51553456201140.png',
#  u'session_id': u'cdm_run_v51553456201140',
#  u'worker_id': u'abc'}
# {u'__v': 0,
#  u'_id': ObjectId('5e7a4d8984f69a325ccf389e'),
#  u'age': u'age4',
#  u'class': u'a hat',
#  u'date': datetime.datetime(2020, 3, 24, 18, 12, 18, 653000),
#  u'filename': u'a hat_sketch_age4_cdm_run_v51555698278732.png',
#  u'session_id': u'cdm_run_v51555698278732',
#  u'worker_id': u'abc'}
# {u'__v': 0,
#  u'_id': ObjectId('5e7a4d8984f69a325ccf389f'),
#  u'age': u'age8',
#  u'class': u'a hat',
#  u'date': datetime.datetime(2020, 3, 24, 18, 12, 19, 507000),
#  u'filename': u'a hat_sketch_age8_cdm_run_v51551909728765.png',
#  u'session_id': u'cdm_run_v51551909728765',
#  u'worker_id': u'abc'}
# {u'__v': 0,
#  u'_id': ObjectId('5e7a4d8984f69a325ccf38a0'),
#  u'age': u'age2',
#  u'class': u'a hat',
#  u'date': datetime.datetime(2020, 3, 24, 18, 12, 20, 133000),
#  u'filename': u'a hat_sketch_age2_cdm_run_v51558550534940.png',
#  u'session_id': u'cdm_run_v51558550534940',
#  u'worker_id': u'abc'}
# {u'__v': 0,
#  u'_id': ObjectId('5e7a4d8984f69a325ccf38a1'),
#  u'age': u'age2',
#  u'class': u'a hat',
#  u'date': datetime.datetime(2020, 3, 24, 18, 12, 20, 721000),
#  u'filename': u'a hat_sketch_age2_cdm_run_v51554328224911.png',
#  u'session_id': u'cdm_run_v51554328224911',
#  u'worker_id': u'abc'}
# {u'__v': 0,
#  u'_id': ObjectId('5e7a4d8984f69a325ccf38a2'),
#  u'age': u'age2',
#  u'class': u'a hat',
#  u'date': datetime.datetime(2020, 3, 24, 18, 12, 21, 284000),
#  u'filename': u'a hat_sketch_age2_cdm_run_v51556042846190.png',
#  u'session_id': u'cdm_run_v51556042846190',
#  u'worker_id': u'abc'}
# {u'__v': 0,
#  u'_id': ObjectId('5e7a4d8984f69a325ccf38a3'),
#  u'age': u'age4',
#  u'class': u'a hat',
#  u'date': datetime.datetime(2020, 3, 24, 18, 12, 22, 33000),
#  u'filename': u'a hat_sketch_age4_cdm_run_v51560016874785.png',
#  u'session_id': u'cdm_run_v51560016874785',
#  u'worker_id': u'abc'}
# {u'__v': 0,
#  u'_id': ObjectId('5e7a4d8984f69a325ccf38a4'),
#  u'age': u'age2',
#  u'class': u'a hat',
#  u'date': datetime.datetime(2020, 3, 24, 18, 12, 22, 924000),
#  u'filename': u'a hat_sketch_age2_cdm_run_v51554665411294.png',
#  u'session_id': u'cdm_run_v51554665411294',
#  u'worker_id': u'abc'}
# {u'__v': 0,
#  u'_id': ObjectId('5e7a4d9b84f69a325ccf38a5'),
#  u'age': u'age3',
#  u'class': u'this square',
#  u'date': datetime.datetime(2020, 3, 24, 18, 12, 29, 167000),
#  u'filename': u'this square_sketch_age3_cdm_run_v51552679039724.png',
#  u'session_id': u'cdm_run_v51552679039724',
#  u'worker_id': u'abc'}
# {u'__v': 0,
#  u'_id': ObjectId('5e7a4d9b84f69a325ccf38a6'),
#  u'age': u'age2',
#  u'class': u'this square',
#  u'date': datetime.datetime(2020, 3, 24, 18, 12, 30, 913000),
#  u'filename': u'this square_sketch_age2_cdm_run_v51551642247832.png',
#  u'session_id': u'cdm_run_v51551642247832',
#  u'worker_id': u'abc'}
# {u'__v': 0,
#  u'_id': ObjectId('5e7a4d9b84f69a325ccf38a7'),
#  u'age': u'age4',
#  u'class': u'this square',
#  u'date': datetime.datetime(2020, 3, 24, 18, 12, 35, 805000),
#  u'filename': u'this square_sketch_age4_cdm_run_v51560196311215.png',
#  u'session_id': u'cdm_run_v51560196311215',
#  u'worker_id': u'abc'}
# {u'__v': 0,
#  u'_id': ObjectId('5e7a4dad84f69a325ccf38a8'),
#  u'age': u'age2',
#  u'class': u'a cactus',
#  u'date': datetime.datetime(2020, 3, 24, 18, 12, 46, 362000),
#  u'filename': u'a cactus_sketch_age2_cdm_run_v51553196050467.png',
#  u'session_id': u'cdm_run_v51553196050467',
#  u'worker_id': u'abc'}
# {u'__v': 0,
#  u'_id': ObjectId('5e7a4dad84f69a325ccf38a9'),
#  u'age': u'age4',
#  u'class': u'a cactus',
#  u'date': datetime.datetime(2020, 3, 24, 18, 12, 47, 266000),
#  u'filename': u'a cactus_sketch_age4_cdm_run_v51554918570394.png',
#  u'session_id': u'cdm_run_v51554918570394',
#  u'worker_id': u'abc'}
# {u'__v': 0,
#  u'_id': ObjectId('5e7a4dad84f69a325ccf38aa'),
#  u'age': u'age9',
#  u'class': u'a cactus',
#  u'date': datetime.datetime(2020, 3, 24, 18, 12, 49, 801000),
#  u'filename': u'a cactus_sketch_age9_cdm_run_v51551647310960.png',
#  u'session_id': u'cdm_run_v51551647310960',
#  u'worker_id': u'abc'}
# {u'__v': 0,
#  u'_id': ObjectId('5e7a4dad84f69a325ccf38ab'),
#  u'age': u'age3',
#  u'class': u'a cactus',
#  u'date': datetime.datetime(2020, 3, 24, 18, 12, 50, 536000),
#  u'filename': u'a cactus_sketch_age3_cdm_run_v51558309513994.png',
#  u'session_id': u'cdm_run_v51558309513994',
#  u'worker_id': u'abc'}
# {u'__v': 0,
#  u'_id': ObjectId('5e7a4dad84f69a325ccf38ac'),
#  u'age': u'age3',
#  u'class': u'a cactus',
#  u'date': datetime.datetime(2020, 3, 24, 18, 12, 51, 329000),
#  u'filename': u'a cactus_sketch_age3_cdm_run_v51557339940060.png',
#  u'session_id': u'cdm_run_v51557339940060',
#  u'worker_id': u'abc'}
# {u'__v': 0,
#  u'_id': ObjectId('5e7a4dad84f69a325ccf38ad'),
#  u'age': u'age2',
#  u'class': u'a cactus',
#  u'date': datetime.datetime(2020, 3, 24, 18, 12, 52, 863000),
#  u'filename': u'a cactus_sketch_age2_cdm_run_v51560368569325.png',
#  u'session_id': u'cdm_run_v51560368569325',
#  u'worker_id': u'abc'}
# {u'__v': 0,
#  u'_id': ObjectId('5e7a4dad84f69a325ccf38ae'),
#  u'age': u'age4',
#  u'class': u'a cactus',
#  u'date': datetime.datetime(2020, 3, 24, 18, 12, 55, 342000),
#  u'filename': u'a cactus_sketch_age4_cdm_run_v51554414374863.png',
#  u'session_id': u'cdm_run_v51554414374863',
#  u'worker_id': u'abc'}
# {u'__v': 0,
#  u'_id': ObjectId('5e7a4dad84f69a325ccf38af'),
#  u'age': u'age2',
#  u'class': u'a cactus',
#  u'date': datetime.datetime(2020, 3, 24, 18, 12, 57, 846000),
#  u'filename': u'a cactus_sketch_age2_cdm_run_v51552170441903.png',
#  u'session_id': u'cdm_run_v51552170441903',
#  u'worker_id': u'abc'}
# {u'__v': 0,
#  u'_id': ObjectId('5e7a4eb184f69a325ccf38b0'),
#  u'age': u'age2',
#  u'class': u'a whale',
#  u'date': datetime.datetime(2020, 3, 24, 18, 17, 20, 201000),
#  u'filename': u'a whale_sketch_age2_cdm_run_v51554831734842.png',
#  u'session_id': u'cdm_run_v51554831734842',
#  u'worker_id': u'abc'}
# {u'__v': 0,
#  u'_id': ObjectId('5e7a4efe84f69a325ccf38b1'),
#  u'age': u'age3',
#  u'class': u'a whale',
#  u'date': datetime.datetime(2020, 3, 24, 18, 18, 27, 840000),
#  u'filename': u'a whale_sketch_age3_cdm_run_v51553983299940.png',
#  u'session_id': u'cdm_run_v51553983299940',
#  u'worker_id': u'abc'}
# {u'__v': 0,
#  u'_id': ObjectId('5e7a4efe84f69a325ccf38b2'),
#  u'age': u'age3',
#  u'class': u'a whale',
#  u'date': datetime.datetime(2020, 3, 24, 18, 18, 29, 915000),
#  u'filename': u'a whale_sketch_age3_cdm_run_v51558912644913.png',
#  u'session_id': u'cdm_run_v51558912644913',
#  u'worker_id': u'abc'}
# {u'__v': 0,
#  u'_id': ObjectId('5e7a4efe84f69a325ccf38b3'),
#  u'age': u'age5',
#  u'class': u'a whale',
#  u'date': datetime.datetime(2020, 3, 24, 18, 18, 33, 130000),
#  u'filename': u'a whale_sketch_age5_cdm_run_v51558476298638.png',
#  u'session_id': u'cdm_run_v51558476298638',
#  u'worker_id': u'abc'}

# %%
# mturk_id
# assignment_id
# trial_id
# hit_id
